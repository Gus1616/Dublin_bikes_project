# %%
import sqlalchemy as sqla
from sqlalchemy import create_engine
import traceback
import glob
import os
from pprint import pprint
import simplejson as json
import requests
import time
from IPython.display import display

# %%
URI = "dbikes.cmd8vuwgew1e.us-east-1.rds.amazonaws.com"
PORT = "3306"
DB = "dbikes"
USER = "admin"

# %%
engine = create_engine("mysql+mysqldb://{}:{}@{}:{}/{}".format(USER, PASSWORD, URI, PORT, DB), echo=True)

# %%
sql = engine.execute(sql)
# Out:
#   Input In [52]
#     INFO sqlalchemy.engine.base.Engine
#          ^
# SyntaxError: invalid syntax

# %%
for res in engine.execute("SHow Variables;"):
    print(res)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:3243, in Engine._wrap_pool_connect(self, fn, connection)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3241'>3242</a> try:
# -> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3242'>3243</a>     return fn()
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3243'>3244</a> except dialect.dbapi.Error as e:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=302'>303</a> """Return a DBAPI connection from the pool.
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=303'>304</a>
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=304'>305</a> The connection is instrumented such that when its
#    (...)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=307'>308</a>
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=308'>309</a> """
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=309'>310</a> return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=866'>867</a> if not fairy:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=867'>868</a>     fairy = _ConnectionRecord.checkout(pool)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=869'>870</a>     fairy._pool = pool
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=473'>474</a> @classmethod
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=474'>475</a> def checkout(cls, pool):
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=475'>476</a>     rec = pool._do_get()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=476'>477</a>     try:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\impl.py:146, in QueuePool._do_get(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=144'>145</a>         with util.safe_reraise():
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=145'>146</a>             self._dec_overflow()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=146'>147</a> else:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\impl.py:143, in QueuePool._do_get(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=141'>142</a> try:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=142'>143</a>     return self._create_connection()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=143'>144</a> except:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:256, in Pool._create_connection(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=253'>254</a> """Called by subclasses to create a new ConnectionRecord."""
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=255'>256</a> return _ConnectionRecord(self)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=369'>370</a> if connect:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=370'>371</a>     self.__connect()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=371'>372</a> self.finalize_callback = deque()
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:666, in _ConnectionRecord.__connect(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=664'>665</a>     with util.safe_reraise():
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=665'>666</a>         pool.logger.debug("Error on connect(): %s", e)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=666'>667</a> else:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=667'>668</a>     # in SQLAlchemy 1.4 the first_connect event is not used by
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=668'>669</a>     # the engine, so this will usually not be set
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:661, in _ConnectionRecord.__connect(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=659'>660</a> self.starttime = time.time()
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=660'>661</a> self.dbapi_connection = connection = pool._invoke_creator(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=661'>662</a> pool.logger.debug("Created new connection %r", connection)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\create.py:590, in create_engine.<locals>.connect(connection_record)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/create.py?line=588'>589</a>             return connection
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/create.py?line=589'>590</a> return dialect.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\default.py:584, in DefaultDialect.connect(self, *cargs, **cparams)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/default.py?line=581'>582</a> def connect(self, *cargs, **cparams):
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/default.py?line=582'>583</a>     # inherits the docstring from interfaces.Dialect.connect
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/default.py?line=583'>584</a>     return self.dbapi.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\MySQLdb\__init__.py:123, in Connect(*args, **kwargs)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/__init__.py?line=120'>121</a> from MySQLdb.connections import Connection
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/__init__.py?line=122'>123</a> return Connection(*args, **kwargs)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\MySQLdb\connections.py:185, in Connection.__init__(self, *args, **kwargs)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=182'>183</a> autocommit = kwargs2.pop("autocommit", False)
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=184'>185</a> super().__init__(*args, **kwargs2)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=185'>186</a> self.cursorclass = cursorclass
#
# OperationalError: (1049, "Unknown database 'database-1'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# c:\Users\michael\Desktop\Dublin_bikes_project\bikes1.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/michael/Desktop/Dublin_bikes_project/bikes1.ipynb#ch0000006?line=0'>1</a> for res in engine.execute("SHow Variables;"):
#       <a href='vscode-notebook-cell:/c%3A/Users/michael/Desktop/Dublin_bikes_project/bikes1.ipynb#ch0000006?line=1'>2</a>     print(res)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\deprecations.py:401, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/deprecations.py?line=398'>399</a> if not skip_warning:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/deprecations.py?line=399'>400</a>     _warn_with_version(message, version, wtype, stacklevel=3)
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/deprecations.py?line=400'>401</a> return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:3138, in Engine.execute(self, statement, *multiparams, **params)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3111'>3112</a> @util.deprecated_20(
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3112'>3113</a>     ":meth:`_engine.Engine.execute`",
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3113'>3114</a>     alternative="All statement execution in SQLAlchemy 2.0 is performed "
#    (...)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3118'>3119</a> )
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3119'>3120</a> def execute(self, statement, *multiparams, **params):
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3120'>3121</a>     """Executes the given construct and returns a
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3121'>3122</a>     :class:`_engine.CursorResult`.
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3122'>3123</a>
#    (...)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3135'>3136</a>
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3136'>3137</a>     """
# -> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3137'>3138</a>     connection = self.connect(close_with_result=True)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3138'>3139</a>     return connection.execute(statement, *multiparams, **params)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:3197, in Engine.connect(self, close_with_result)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3181'>3182</a> def connect(self, close_with_result=False):
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3182'>3183</a>     """Return a new :class:`_engine.Connection` object.
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3183'>3184</a>
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3184'>3185</a>     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3193'>3194</a>
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3194'>3195</a>     """
# -> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3196'>3197</a>     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=90'>91</a>     self._has_events = _branch_from._has_events
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=91'>92</a> else:
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=92'>93</a>     self._dbapi_connection = (
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=93'>94</a>         connection
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=94'>95</a>         if connection is not None
# ---> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=95'>96</a>         else engine.raw_connection()
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=96'>97</a>     )
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=98'>99</a>     self._transaction = self._nested_transaction = None
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=99'>100</a>     self.__savepoint_seq = 0
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:3276, in Engine.raw_connection(self, _connection)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3253'>3254</a> def raw_connection(self, _connection=None):
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3254'>3255</a>     """Return a "raw" DBAPI connection from the connection pool.
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3255'>3256</a>
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3256'>3257</a>     The returned object is a proxied version of the DBAPI
#    (...)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3273'>3274</a>
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3274'>3275</a>     """
# -> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3275'>3276</a>     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:3246, in Engine._wrap_pool_connect(self, fn, connection)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3243'>3244</a> except dialect.dbapi.Error as e:
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3244'>3245</a>     if connection is None:
# -> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3245'>3246</a>         Connection._handle_dbapi_exception_noconnection(
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3246'>3247</a>             e, dialect, self
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3247'>3248</a>         )
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3248'>3249</a>     else:
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3249'>3250</a>         util.raise_(
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3250'>3251</a>             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3251'>3252</a>         )
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:2100, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=2097'>2098</a>     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=2098'>2099</a> elif should_wrap:
# -> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=2099'>2100</a>     util.raise_(
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=2100'>2101</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=2101'>2102</a>     )
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=2102'>2103</a> else:
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=2103'>2104</a>     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\base.py:3243, in Engine._wrap_pool_connect(self, fn, connection)
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3240'>3241</a> dialect = self.dialect
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3241'>3242</a> try:
# -> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3242'>3243</a>     return fn()
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3243'>3244</a> except dialect.dbapi.Error as e:
#    <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/base.py?line=3244'>3245</a>     if connection is None:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=301'>302</a> def connect(self):
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=302'>303</a>     """Return a DBAPI connection from the pool.
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=303'>304</a>
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=304'>305</a>     The connection is instrumented such that when its
#    (...)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=307'>308</a>
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=308'>309</a>     """
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=309'>310</a>     return _ConnectionFairy._checkout(self)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=864'>865</a> @classmethod
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=865'>866</a> def _checkout(cls, pool, threadconns=None, fairy=None):
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=866'>867</a>     if not fairy:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=867'>868</a>         fairy = _ConnectionRecord.checkout(pool)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=869'>870</a>         fairy._pool = pool
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=870'>871</a>         fairy._counter = 0
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=473'>474</a> @classmethod
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=474'>475</a> def checkout(cls, pool):
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=475'>476</a>     rec = pool._do_get()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=476'>477</a>     try:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=477'>478</a>         dbapi_connection = rec.get_connection()
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\impl.py:146, in QueuePool._do_get(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=143'>144</a>     except:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=144'>145</a>         with util.safe_reraise():
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=145'>146</a>             self._dec_overflow()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=146'>147</a> else:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=147'>148</a>     return self._do_get()
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=67'>68</a>     self._exc_info = None  # remove potential circular references
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=74'>75</a>     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=75'>76</a>         # emulate Py3K's behavior of telling us when an exception
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=76'>77</a>         # occurs in an exception handler.
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\impl.py:143, in QueuePool._do_get(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=140'>141</a> if self._inc_overflow():
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=141'>142</a>     try:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=142'>143</a>         return self._create_connection()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=143'>144</a>     except:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/impl.py?line=144'>145</a>         with util.safe_reraise():
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:256, in Pool._create_connection(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=252'>253</a> def _create_connection(self):
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=253'>254</a>     """Called by subclasses to create a new ConnectionRecord."""
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=255'>256</a>     return _ConnectionRecord(self)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=368'>369</a> self.__pool = pool
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=369'>370</a> if connect:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=370'>371</a>     self.__connect()
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=371'>372</a> self.finalize_callback = deque()
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:666, in _ConnectionRecord.__connect(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=663'>664</a> except Exception as e:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=664'>665</a>     with util.safe_reraise():
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=665'>666</a>         pool.logger.debug("Error on connect(): %s", e)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=666'>667</a> else:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=667'>668</a>     # in SQLAlchemy 1.4 the first_connect event is not used by
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=668'>669</a>     # the engine, so this will usually not be set
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=669'>670</a>     if pool.dispatch.first_connect:
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=67'>68</a>     self._exc_info = None  # remove potential circular references
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=68'>69</a>     if not self.warn_only:
# ---> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=69'>70</a>         compat.raise_(
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=70'>71</a>             exc_value,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=71'>72</a>             with_traceback=exc_tb,
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=72'>73</a>         )
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=73'>74</a> else:
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=74'>75</a>     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=75'>76</a>         # emulate Py3K's behavior of telling us when an exception
#      <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/langhelpers.py?line=76'>77</a>         # occurs in an exception handler.
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=203'>204</a>     exception.__cause__ = replace_context
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/util/compat.py?line=211'>212</a>     del exception, replace_context, from_, with_traceback
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\pool\base.py:661, in _ConnectionRecord.__connect(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=658'>659</a> try:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=659'>660</a>     self.starttime = time.time()
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=660'>661</a>     self.dbapi_connection = connection = pool._invoke_creator(self)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=661'>662</a>     pool.logger.debug("Created new connection %r", connection)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/pool/base.py?line=662'>663</a>     self.fresh = True
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\create.py:590, in create_engine.<locals>.connect(connection_record)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/create.py?line=587'>588</a>         if connection is not None:
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/create.py?line=588'>589</a>             return connection
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/create.py?line=589'>590</a> return dialect.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\sqlalchemy\engine\default.py:584, in DefaultDialect.connect(self, *cargs, **cparams)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/default.py?line=581'>582</a> def connect(self, *cargs, **cparams):
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/default.py?line=582'>583</a>     # inherits the docstring from interfaces.Dialect.connect
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/sqlalchemy/engine/default.py?line=583'>584</a>     return self.dbapi.connect(*cargs, **cparams)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\MySQLdb\__init__.py:123, in Connect(*args, **kwargs)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/__init__.py?line=119'>120</a> """Factory function for connections.Connection."""
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/__init__.py?line=120'>121</a> from MySQLdb.connections import Connection
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/__init__.py?line=122'>123</a> return Connection(*args, **kwargs)
#
# File ~\anaconda3\envs\comp30830\lib\site-packages\MySQLdb\connections.py:185, in Connection.__init__(self, *args, **kwargs)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=181'>182</a> # PEP-249 requires autocommit to be initially off
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=182'>183</a> autocommit = kwargs2.pop("autocommit", False)
# --> <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=184'>185</a> super().__init__(*args, **kwargs2)
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=185'>186</a> self.cursorclass = cursorclass
#     <a href='file:///~/anaconda3/envs/comp30830/lib/site-packages/MySQLdb/connections.py?line=186'>187</a> self.encoders = {k: v for k, v in conv.items() if type(k) is not int}
#
# OperationalError: (MySQLdb._exceptions.OperationalError) (1049, "Unknown database 'database-1'")
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
