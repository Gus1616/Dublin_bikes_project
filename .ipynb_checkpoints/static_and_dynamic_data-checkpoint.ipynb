# %%
import sqlalchemy as sqla
from sqlalchemy import create_engine
import traceback
import glob
import os
from pprint import pprint
import simplejson as json
import requests
import time
from IPython.display import display

# %%
URI = "dbikes2.cmd8vuwgew1e.us-east-1.rds.amazonaws.com"
PORT = "3306"
DB = "dbikes"
USER = "admin"
PASSWORD = "Dublin123"

# %%
engine = create_engine("mysql+mysqldb://{}:{}@{}:{}/{}".format(USER, PASSWORD, URI, PORT, DB), echo=True)

# %%
sql = '''
CREATE DATABASE IF NOT EXISTS dbikes;
'''
engine.execute(sql)
# Out:
# 2022-02-16 20:59:07,120 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2022-02-16 20:59:07,126 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-16 20:59:07,239 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2022-02-16 20:59:07,239 INFO sqlalchemy.engine.Engine [generated in 0.00192s] ()
# 2022-02-16 20:59:07,482 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-02-16 20:59:07,482 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-16 20:59:07,842 INFO sqlalchemy.engine.Engine
# CREATE DATABASE IF NOT EXISTS dbikes;
#
# 2022-02-16 20:59:07,842 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-16 20:59:07,965 INFO sqlalchemy.engine.Engine COMMIT

# %%
for res in engine.execute("SHow Variables;"):
    print(res)
# Out:
# 2022-02-16 20:59:08,248 INFO sqlalchemy.engine.Engine SHow Variables;
# 2022-02-16 20:59:08,252 INFO sqlalchemy.engine.Engine [raw sql] ()
# ('activate_all_roles_on_login', 'OFF')
# ('admin_address', '')
# ('admin_port', '33062')
# ('admin_ssl_ca', '')
# ('admin_ssl_capath', '')
# ('admin_ssl_cert', '')
# ('admin_ssl_cipher', '')
# ('admin_ssl_crl', '')
# ('admin_ssl_crlpath', '')
# ('admin_ssl_key', '')
# ('admin_tls_ciphersuites', '')
# ('admin_tls_version', 'TLSv1,TLSv1.1,TLSv1.2,TLSv1.3')
# ('authentication_policy', '*')
# ('auto_generate_certs', 'ON')
# ('auto_increment_increment', '1')
# ('auto_increment_offset', '1')
# ('autocommit', 'OFF')
# ('automatic_sp_privileges', 'ON')
# ('avoid_temporal_upgrade', 'OFF')
# ('back_log', '65')
# ('basedir', '/rdsdbbin/mysql-8.0.27.R3/')
# ('big_tables', 'OFF')
# ('bind_address', '*')
# ('binlog_cache_size', '32768')
# ('binlog_checksum', 'CRC32')
# ('binlog_direct_non_transactional_updates', 'OFF')
# ('binlog_encryption', 'OFF')
# ('binlog_error_action', 'ABORT_SERVER')
# ('binlog_expire_logs_seconds', '2592000')
# ('binlog_format', 'MIXED')
# ('binlog_group_commit_sync_delay', '0')
# ('binlog_group_commit_sync_no_delay_count', '0')
# ('binlog_gtid_simple_recovery', 'ON')
# ('binlog_max_flush_queue_time', '0')
# ('binlog_order_commits', 'ON')
# ('binlog_rotate_encryption_master_key_at_startup', 'OFF')
# ('binlog_row_event_max_size', '8192')
# ('binlog_row_image', 'FULL')
# ('binlog_row_metadata', 'MINIMAL')
# ('binlog_row_value_options', '')
# ('binlog_rows_query_log_events', 'OFF')
# ('binlog_stmt_cache_size', '32768')
# ('binlog_transaction_compression', 'OFF')
# ('binlog_transaction_compression_level_zstd', '3')
# ('binlog_transaction_dependency_history_size', '25000')
# ('binlog_transaction_dependency_tracking', 'COMMIT_ORDER')
# ('block_encryption_mode', 'aes-128-ecb')
# ('bulk_insert_buffer_size', '8388608')
# ('caching_sha2_password_auto_generate_rsa_keys', 'ON')
# ('caching_sha2_password_digest_rounds', '5000')
# ('caching_sha2_password_private_key_path', 'private_key.pem')
# ('caching_sha2_password_public_key_path', 'public_key.pem')
# ('character_set_client', 'utf8mb4')
# ('character_set_connection', 'utf8mb4')
# ('character_set_database', 'utf8mb4')
# ('character_set_filesystem', 'binary')
# ('character_set_results', 'utf8mb4')
# ('character_set_server', 'utf8mb4')
# ('character_set_system', 'utf8mb3')
# ('character_sets_dir', '/rdsdbbin/mysql-8.0.27.R3/share/charsets/')
# ('check_proxy_users', 'OFF')
# ('collation_connection', 'utf8mb4_0900_ai_ci')
# ('collation_database', 'utf8mb4_0900_ai_ci')
# ('collation_server', 'utf8mb4_0900_ai_ci')
# ('completion_type', 'NO_CHAIN')
# ('concurrent_insert', 'AUTO')
# ('connect_timeout', '10')
# ('core_file', 'OFF')
# ('create_admin_listener_thread', 'OFF')
# ('cte_max_recursion_depth', '1000')
# ('datadir', '/rdsdbdata/db/')
# ('default_authentication_plugin', 'mysql_native_password')
# ('default_collation_for_utf8mb4', 'utf8mb4_0900_ai_ci')
# ('default_password_lifetime', '0')
# ('default_storage_engine', 'InnoDB')
# ('default_table_encryption', 'OFF')
# ('default_tmp_storage_engine', 'InnoDB')
# ('default_week_format', '0')
# ('delay_key_write', 'ON')
# ('delayed_insert_limit', '100')
# ('delayed_insert_timeout', '300')
# ('delayed_queue_size', '1000')
# ('disabled_storage_engines', '')
# ('disconnect_on_expired_password', 'ON')
# ('div_precision_increment', '4')
# ('end_markers_in_json', 'OFF')
# ('enforce_gtid_consistency', 'OFF')
# ('eq_range_index_dive_limit', '200')
# ('error_count', '0')
# ('event_scheduler', 'ON')
# ('expire_logs_days', '0')
# ('explicit_defaults_for_timestamp', 'ON')
# ('external_user', '')
# ('flush', 'OFF')
# ('flush_time', '0')
# ('foreign_key_checks', 'ON')
# ('ft_boolean_syntax', '+ -><()~*:""&|')
# ('ft_max_word_len', '84')
# ('ft_min_word_len', '4')
# ('ft_query_expansion_limit', '20')
# ('ft_stopword_file', '(built-in)')
# ('general_log', 'OFF')
# ('general_log_file', '/rdsdbdata/log/general/mysql-general.log')
# ('generated_random_password_length', '20')
# ('group_concat_max_len', '1024')
# ('group_replication_consistency', 'EVENTUAL')
# ('gtid_executed', '')
# ('gtid_executed_compression_period', '0')
# ('gtid_mode', 'OFF_PERMISSIVE')
# ('gtid_next', 'AUTOMATIC')
# ('gtid_owned', '')
# ('gtid_purged', '')
# ('have_compress', 'YES')
# ('have_dynamic_loading', 'YES')
# ('have_geometry', 'YES')
# ('have_openssl', 'YES')
# ('have_profiling', 'YES')
# ('have_query_cache', 'NO')
# ('have_rtree_keys', 'YES')
# ('have_ssl', 'YES')
# ('have_statement_timeout', 'YES')
# ('have_symlink', 'DISABLED')
# ('histogram_generation_max_mem_size', '20000000')
# ('host_cache_size', '193')
# ('hostname', 'ip-10-1-1-173')
# ('identity', '0')
# ('immediate_server_version', '999999')
# ('information_schema_stats_expiry', '86400')
# ('init_connect', '')
# ('init_file', '')
# ('init_replica', '')
# ('init_slave', '')
# ('innodb_adaptive_flushing', 'ON')
# ('innodb_adaptive_flushing_lwm', '10')
# ('innodb_adaptive_hash_index', 'ON')
# ('innodb_adaptive_hash_index_parts', '8')
# ('innodb_adaptive_max_sleep_delay', '150000')
# ('innodb_api_bk_commit_interval', '5')
# ('innodb_api_disable_rowlock', 'OFF')
# ('innodb_api_enable_binlog', 'OFF')
# ('innodb_api_enable_mdl', 'OFF')
# ('innodb_api_trx_level', '0')
# ('innodb_autoextend_increment', '64')
# ('innodb_autoinc_lock_mode', '2')
# ('innodb_buffer_pool_chunk_size', '134217728')
# ('innodb_buffer_pool_dump_at_shutdown', 'ON')
# ('innodb_buffer_pool_dump_now', 'OFF')
# ('innodb_buffer_pool_dump_pct', '25')
# ('innodb_buffer_pool_filename', 'ib_buffer_pool')
# ('innodb_buffer_pool_in_core_file', 'ON')
# ('innodb_buffer_pool_instances', '1')
# ('innodb_buffer_pool_load_abort', 'OFF')
# ('innodb_buffer_pool_load_at_startup', 'ON')
# ('innodb_buffer_pool_load_now', 'OFF')
# ('innodb_buffer_pool_size', '268435456')
# ('innodb_change_buffer_max_size', '25')
# ('innodb_change_buffering', 'all')
# ('innodb_checksum_algorithm', 'crc32')
# ('innodb_cmp_per_index_enabled', 'OFF')
# ('innodb_commit_concurrency', '0')
# ('innodb_compression_failure_threshold_pct', '5')
# ('innodb_compression_level', '6')
# ('innodb_compression_pad_pct_max', '50')
# ('innodb_concurrency_tickets', '5000')
# ('innodb_data_file_path', 'ibdata1:12M:autoextend')
# ('innodb_data_home_dir', '/rdsdbdata/db/innodb')
# ('innodb_ddl_buffer_size', '1048576')
# ('innodb_ddl_threads', '4')
# ('innodb_deadlock_detect', 'ON')
# ('innodb_dedicated_server', 'OFF')
# ('innodb_default_row_format', 'dynamic')
# ('innodb_directories', '')
# ('innodb_disable_sort_file_cache', 'OFF')
# ('innodb_doublewrite', 'ON')
# ('innodb_doublewrite_batch_size', '16')
# ('innodb_doublewrite_dir', '')
# ('innodb_doublewrite_files', '2')
# ('innodb_doublewrite_pages', '32')
# ('innodb_extend_and_initialize', 'ON')
# ('innodb_fast_shutdown', '1')
# ('innodb_file_per_table', 'ON')
# ('innodb_fill_factor', '100')
# ('innodb_flush_log_at_timeout', '1')
# ('innodb_flush_log_at_trx_commit', '1')
# ('innodb_flush_method', 'O_DIRECT')
# ('innodb_flush_neighbors', '0')
# ('innodb_flush_sync', 'ON')
# ('innodb_flushing_avg_loops', '30')
# ('innodb_force_load_corrupted', 'OFF')
# ('innodb_force_recovery', '0')
# ('innodb_fsync_threshold', '0')
# ('innodb_ft_aux_table', '')
# ('innodb_ft_cache_size', '8000000')
# ('innodb_ft_enable_diag_print', 'OFF')
# ('innodb_ft_enable_stopword', 'ON')
# ('innodb_ft_max_token_size', '84')
# ('innodb_ft_min_token_size', '3')
# ('innodb_ft_num_word_optimize', '2000')
# ('innodb_ft_result_cache_limit', '2000000000')
# ('innodb_ft_server_stopword_table', '')
# ('innodb_ft_sort_pll_degree', '2')
# ('innodb_ft_total_cache_size', '640000000')
# ('innodb_ft_user_stopword_table', '')
# ('innodb_idle_flush_pct', '100')
# ('innodb_io_capacity', '200')
# ('innodb_io_capacity_max', '2000')
# ('innodb_lock_wait_timeout', '50')
# ('innodb_log_buffer_size', '8388608')
# ('innodb_log_checksums', 'ON')
# ('innodb_log_compressed_pages', 'ON')
# ('innodb_log_file_size', '134217728')
# ('innodb_log_files_in_group', '2')
# ('innodb_log_group_home_dir', '/rdsdbdata/log/innodb')
# ('innodb_log_spin_cpu_abs_lwm', '80')
# ('innodb_log_spin_cpu_pct_hwm', '50')
# ('innodb_log_wait_for_flush_spin_hwm', '400')
# ('innodb_log_write_ahead_size', '8192')
# ('innodb_log_writer_threads', 'ON')
# ('innodb_lru_scan_depth', '1024')
# ('innodb_max_dirty_pages_pct', '90.000000')
# ('innodb_max_dirty_pages_pct_lwm', '10.000000')
# ('innodb_max_purge_lag', '0')
# ('innodb_max_purge_lag_delay', '0')
# ('innodb_max_undo_log_size', '1073741824')
# ('innodb_monitor_disable', '')
# ('innodb_monitor_enable', '')
# ('innodb_monitor_reset', '')
# ('innodb_monitor_reset_all', '')
# ('innodb_numa_interleave', 'OFF')
# ('innodb_old_blocks_pct', '37')
# ('innodb_old_blocks_time', '1000')
# ('innodb_online_alter_log_max_size', '134217728')
# ('innodb_open_files', '4000')
# ('innodb_optimize_fulltext_only', 'OFF')
# ('innodb_page_cleaners', '1')
# ('innodb_page_size', '16384')
# ('innodb_parallel_read_threads', '4')
# ('innodb_print_all_deadlocks', 'OFF')
# ('innodb_print_ddl_logs', 'OFF')
# ('innodb_purge_batch_size', '300')
# ('innodb_purge_rseg_truncate_frequency', '128')
# ('innodb_purge_threads', '1')
# ('innodb_random_read_ahead', 'OFF')
# ('innodb_read_ahead_threshold', '56')
# ('innodb_read_io_threads', '4')
# ('innodb_read_only', 'OFF')
# ('innodb_redo_log_archive_dirs', '')
# ('innodb_redo_log_encrypt', 'OFF')
# ('innodb_replication_delay', '0')
# ('innodb_rollback_on_timeout', 'OFF')
# ('innodb_rollback_segments', '128')
# ('innodb_segment_reserve_factor', '12.500000')
# ('innodb_sort_buffer_size', '1048576')
# ('innodb_spin_wait_delay', '6')
# ('innodb_spin_wait_pause_multiplier', '50')
# ('innodb_stats_auto_recalc', 'ON')
# ('innodb_stats_include_delete_marked', 'OFF')
# ('innodb_stats_method', 'nulls_equal')
# ('innodb_stats_on_metadata', 'OFF')
# ('innodb_stats_persistent', 'ON')
# ('innodb_stats_persistent_sample_pages', '20')
# ('innodb_stats_transient_sample_pages', '8')
# ('innodb_status_output', 'OFF')
# ('innodb_status_output_locks', 'OFF')
# ('innodb_strict_mode', 'ON')
# ('innodb_sync_array_size', '1')
# ('innodb_sync_spin_loops', '30')
# ('innodb_table_locks', 'ON')
# ('innodb_temp_data_file_path', 'ibtmp1:12M:autoextend')
# ('innodb_temp_tablespaces_dir', './#innodb_temp/')
# ('innodb_thread_concurrency', '0')
# ('innodb_thread_sleep_delay', '10000')
# ('innodb_tmpdir', '')
# ('innodb_undo_directory', './')
# ('innodb_undo_log_encrypt', 'OFF')
# ('innodb_undo_log_truncate', 'ON')
# ('innodb_undo_tablespaces', '2')
# ('innodb_use_fdatasync', 'OFF')
# ('innodb_use_native_aio', 'ON')
# ('innodb_validate_tablespace_paths', 'ON')
# ('innodb_version', '8.0.27')
# ('innodb_write_io_threads', '4')
# ('insert_id', '0')
# ('interactive_timeout', '28800')
# ('internal_tmp_mem_storage_engine', 'TempTable')
# ('join_buffer_size', '262144')
# ('keep_files_on_create', 'OFF')
# ('key_buffer_size', '16777216')
# ('key_cache_age_threshold', '300')
# ('key_cache_block_size', '1024')
# ('key_cache_division_limit', '100')
# ('keyring_operations', 'ON')
# ('large_files_support', 'ON')
# ('large_page_size', '0')
# ('large_pages', 'OFF')
# ('last_insert_id', '0')
# ('lc_messages', 'en_US')
# ('lc_messages_dir', '/rdsdbbin/mysql-8.0.27.R3/share/')
# ('lc_time_names', 'en_US')
# ('license', 'GPL')
# ('local_infile', 'ON')
# ('lock_wait_timeout', '31536000')
# ('locked_in_memory', 'OFF')
# ('log_bin', 'ON')
# ('log_bin_basename', '/rdsdbdata/log/binlog/mysql-bin-changelog')
# ('log_bin_index', '/rdsdbdata/log/binlog/mysql-bin-changelog.index')
# ('log_bin_trust_function_creators', 'OFF')
# ('log_bin_use_v1_row_events', 'OFF')
# ('log_error', '/rdsdbdata/log/error/mysql-error.log')
# ('log_error_services', 'log_filter_internal; log_sink_internal')
# ('log_error_suppression_list', '')
# ('log_error_verbosity', '2')
# ('log_output', 'TABLE')
# ('log_queries_not_using_indexes', 'OFF')
# ('log_raw', 'OFF')
# ('log_replica_updates', 'ON')
# ('log_slave_updates', 'ON')
# ('log_slow_admin_statements', 'OFF')
# ('log_slow_extra', 'OFF')
# ('log_slow_replica_statements', 'OFF')
# ('log_slow_slave_statements', 'OFF')
# ('log_statements_unsafe_for_binlog', 'OFF')
# ('log_throttle_queries_not_using_indexes', '0')
# ('log_timestamps', 'UTC')
# ('long_query_time', '10.000000')
# ('low_priority_updates', 'OFF')
# ('lower_case_file_system', 'OFF')
# ('lower_case_table_names', '0')
# ('mandatory_roles', '')
# ('master_info_repository', 'TABLE')
# ('master_verify_checksum', 'OFF')
# ('max_allowed_packet', '67108864')
# ('max_binlog_cache_size', '18446744073709547520')
# ('max_binlog_size', '134217728')
# ('max_binlog_stmt_cache_size', '18446744073709547520')
# ('max_connect_errors', '100')
# ('max_connections', '65')
# ('max_delayed_threads', '20')
# ('max_digest_length', '1024')
# ('max_error_count', '1024')
# ('max_execution_time', '0')
# ('max_heap_table_size', '16777216')
# ('max_insert_delayed_threads', '20')
# ('max_join_size', '18446744073709551615')
# ('max_length_for_sort_data', '4096')
# ('max_points_in_geometry', '65536')
# ('max_prepared_stmt_count', '16382')
# ('max_relay_log_size', '0')
# ('max_seeks_for_key', '18446744073709551615')
# ('max_sort_length', '1024')
# ('max_sp_recursion_depth', '0')
# ('max_user_connections', '0')
# ('max_write_lock_count', '18446744073709551615')
# ('min_examined_row_limit', '0')
# ('myisam_data_pointer_size', '6')
# ('myisam_max_sort_file_size', '9223372036853727232')
# ('myisam_mmap_size', '18446744073709551615')
# ('myisam_recover_options', 'OFF')
# ('myisam_repair_threads', '1')
# ('myisam_sort_buffer_size', '8388608')
# ('myisam_stats_method', 'nulls_unequal')
# ('myisam_use_mmap', 'OFF')
# ('mysql_native_password_proxy_users', 'OFF')
# ('net_buffer_length', '16384')
# ('net_read_timeout', '30')
# ('net_retry_count', '10')
# ('net_write_timeout', '60')
# ('new', 'OFF')
# ('ngram_token_size', '2')
# ('offline_mode', 'OFF')
# ('old', 'OFF')
# ('old_alter_table', 'OFF')
# ('open_files_limit', '65535')
# ('optimizer_prune_level', '1')
# ('optimizer_search_depth', '62')
# ('optimizer_switch', 'index_merge=on,index_merge_union=on,index_merge_sort_union=on,index_merge_intersection=on,engine_condition_pushdown=on,index_condition_pushdown=on,mr ... (258 characters truncated) ... visible_indexes=off,skip_scan=on,hash_join=on,subquery_to_derived=off,prefer_ordering_index=on,hypergraph_optimizer=off,derived_condition_pushdown=on')
# ('optimizer_trace', 'enabled=off,one_line=off')
# ('optimizer_trace_features', 'greedy_search=on,range_optimizer=on,dynamic_range=on,repeated_subselect=on')
# ('optimizer_trace_limit', '1')
# ('optimizer_trace_max_mem_size', '1048576')
# ('optimizer_trace_offset', '-1')
# ('original_commit_timestamp', '36028797018963968')
# ('original_server_version', '999999')
# ('parser_max_mem_size', '18446744073709551615')
# ('partial_revokes', 'OFF')
# ('password_history', '0')
# ('password_require_current', 'OFF')
# ('password_reuse_interval', '0')
# ('performance_schema', 'OFF')
# ('performance_schema_accounts_size', '0')
# ('performance_schema_digests_size', '0')
# ('performance_schema_error_size', '0')
# ('performance_schema_events_stages_history_long_size', '0')
# ('performance_schema_events_stages_history_size', '0')
# ('performance_schema_events_statements_history_long_size', '0')
# ('performance_schema_events_statements_history_size', '0')
# ('performance_schema_events_transactions_history_long_size', '0')
# ('performance_schema_events_transactions_history_size', '0')
# ('performance_schema_events_waits_history_long_size', '0')
# ('performance_schema_events_waits_history_size', '0')
# ('performance_schema_hosts_size', '0')
# ('performance_schema_max_cond_classes', '0')
# ('performance_schema_max_cond_instances', '0')
# ('performance_schema_max_digest_length', '0')
# ('performance_schema_max_digest_sample_age', '60')
# ('performance_schema_max_file_classes', '0')
# ('performance_schema_max_file_handles', '0')
# ('performance_schema_max_file_instances', '0')
# ('performance_schema_max_index_stat', '0')
# ('performance_schema_max_memory_classes', '0')
# ('performance_schema_max_metadata_locks', '0')
# ('performance_schema_max_mutex_classes', '0')
# ('performance_schema_max_mutex_instances', '0')
# ('performance_schema_max_prepared_statements_instances', '0')
# ('performance_schema_max_program_instances', '0')
# ('performance_schema_max_rwlock_classes', '0')
# ('performance_schema_max_rwlock_instances', '0')
# ('performance_schema_max_socket_classes', '0')
# ('performance_schema_max_socket_instances', '0')
# ('performance_schema_max_sql_text_length', '0')
# ('performance_schema_max_stage_classes', '0')
# ('performance_schema_max_statement_classes', '0')
# ('performance_schema_max_statement_stack', '0')
# ('performance_schema_max_table_handles', '0')
# ('performance_schema_max_table_instances', '0')
# ('performance_schema_max_table_lock_stat', '0')
# ('performance_schema_max_thread_classes', '0')
# ('performance_schema_max_thread_instances', '0')
# ('performance_schema_session_connect_attrs_size', '0')
# ('performance_schema_setup_actors_size', '0')
# ('performance_schema_setup_objects_size', '0')
# ('performance_schema_show_processlist', 'OFF')
# ('performance_schema_users_size', '0')
# ('persist_only_admin_x509_subject', '')
# ('persisted_globals_load', 'OFF')
# ('pid_file', '/rdsdbdata/log/mysql-3306.pid')
# ('plugin_dir', '/rdsdbbin/mysql-8.0.27.R3/lib/plugin/')
# ('port', '3306')
# ('preload_buffer_size', '32768')
# ('print_identified_with_as_hex', 'OFF')
# ('profiling', 'OFF')
# ('profiling_history_size', '15')
# ('protocol_compression_algorithms', 'zlib,zstd,uncompressed')
# ('protocol_version', '10')
# ('proxy_user', '')
# ('pseudo_replica_mode', 'OFF')
# ('pseudo_slave_mode', 'OFF')
# ('pseudo_thread_id', '792')
# ('query_alloc_block_size', '8192')
# ('query_prealloc_size', '8192')
# ('rand_seed1', '0')
# ('rand_seed2', '0')
# ('range_alloc_block_size', '4096')
# ('range_optimizer_max_mem_size', '8388608')
# ('rbr_exec_mode', 'STRICT')
# ('read_buffer_size', '262144')
# ('read_only', 'OFF')
# ('read_rnd_buffer_size', '524288')
# ('regexp_stack_limit', '8000000')
# ('regexp_time_limit', '32')
# ('relay_log', '/rdsdbdata/log/relaylog/relaylog')
# ('relay_log_basename', '/rdsdbdata/log/relaylog/relaylog')
# ('relay_log_index', '/rdsdbdata/log/relaylog/relaylog.index')
# ('relay_log_info_file', 'relay-log.info')
# ('relay_log_info_repository', 'TABLE')
# ('relay_log_purge', 'ON')
# ('relay_log_recovery', 'ON')
# ('relay_log_space_limit', '0')
# ('replica_allow_batching', 'OFF')
# ('replica_checkpoint_group', '512')
# ('replica_checkpoint_period', '300')
# ('replica_compressed_protocol', 'OFF')
# ('replica_exec_mode', 'IDEMPOTENT')
# ('replica_load_tmpdir', '/tmp')
# ('replica_max_allowed_packet', '1073741824')
# ('replica_net_timeout', '60')
# ('replica_parallel_type', 'LOGICAL_CLOCK')
# ('replica_parallel_workers', '4')
# ('replica_pending_jobs_size_max', '134217728')
# ('replica_preserve_commit_order', 'ON')
# ('replica_skip_errors', 'OFF')
# ('replica_sql_verify_checksum', 'ON')
# ('replica_transaction_retries', '10')
# ('replica_type_conversions', '')
# ('replication_optimize_for_static_plugin_config', 'OFF')
# ('replication_sender_observe_commit_only', 'OFF')
# ('report_host', '')
# ('report_password', '')
# ('report_port', '3306')
# ('report_user', '')
# ('require_row_format', 'OFF')
# ('require_secure_transport', 'OFF')
# ('resultset_metadata', 'FULL')
# ('rpl_read_size', '8192')
# ('rpl_stop_replica_timeout', '31536000')
# ('rpl_stop_slave_timeout', '31536000')
# ('schema_definition_cache', '256')
# ('secondary_engine_cost_threshold', '100000.000000')
# ('secure_file_priv', '/secure_file_priv_dir/')
# ('select_into_buffer_size', '131072')
# ('select_into_disk_sync', 'OFF')
# ('select_into_disk_sync_delay', '0')
# ('server_id', '1617168583')
# ('server_id_bits', '32')
# ('server_uuid', 'e082718a-8e49-11ec-a38b-16b054ded28d')
# ('session_track_gtids', 'OFF')
# ('session_track_schema', 'ON')
# ('session_track_state_change', 'OFF')
# ('session_track_system_variables', 'time_zone,autocommit,character_set_client,character_set_results,character_set_connection')
# ('session_track_transaction_info', 'OFF')
# ('sha256_password_auto_generate_rsa_keys', 'ON')
# ('sha256_password_private_key_path', 'private_key.pem')
# ('sha256_password_proxy_users', 'OFF')
# ('sha256_password_public_key_path', 'public_key.pem')
# ('show_create_table_skip_secondary_engine', 'OFF')
# ('show_create_table_verbosity', 'OFF')
# ('show_old_temporals', 'OFF')
# ('skip_external_locking', 'ON')
# ('skip_name_resolve', 'OFF')
# ('skip_networking', 'OFF')
# ('skip_replica_start', 'ON')
# ('skip_show_database', 'OFF')
# ('skip_slave_start', 'ON')
# ('slave_allow_batching', 'OFF')
# ('slave_checkpoint_group', '512')
# ('slave_checkpoint_period', '300')
# ('slave_compressed_protocol', 'OFF')
# ('slave_exec_mode', 'IDEMPOTENT')
# ('slave_load_tmpdir', '/tmp')
# ('slave_max_allowed_packet', '1073741824')
# ('slave_net_timeout', '60')
# ('slave_parallel_type', 'LOGICAL_CLOCK')
# ('slave_parallel_workers', '4')
# ('slave_pending_jobs_size_max', '134217728')
# ('slave_preserve_commit_order', 'ON')
# ('slave_rows_search_algorithms', 'INDEX_SCAN,HASH_SCAN')
# ('slave_skip_errors', 'OFF')
# ('slave_sql_verify_checksum', 'ON')
# ('slave_transaction_retries', '10')
# ('slave_type_conversions', '')
# ('slow_launch_time', '2')
# ('slow_query_log', 'OFF')
# ('slow_query_log_file', '/rdsdbdata/log/slowquery/mysql-slowquery.log')
# ('socket', '/tmp/mysql.sock')
# ('sort_buffer_size', '262144')
# ('source_verify_checksum', 'OFF')
# ('sql_auto_is_null', 'OFF')
# ('sql_big_selects', 'ON')
# ('sql_buffer_result', 'OFF')
# ('sql_log_bin', 'ON')
# ('sql_log_off', 'OFF')
# ('sql_mode', 'NO_ENGINE_SUBSTITUTION')
# ('sql_notes', 'ON')
# ('sql_quote_show_create', 'ON')
# ('sql_replica_skip_counter', '0')
# ('sql_require_primary_key', 'OFF')
# ('sql_safe_updates', 'OFF')
# ('sql_select_limit', '18446744073709551615')
# ('sql_slave_skip_counter', '0')
# ('sql_warnings', 'OFF')
# ('ssl_ca', '/rdsdbdata/rds-metadata/ca-cert.pem')
# ('ssl_capath', '')
# ('ssl_cert', '/rdsdbdata/rds-metadata/server-cert.pem')
# ('ssl_cipher', 'ECDHE-RSA-AES256-GCM-SHA384:ECDHE-RSA-AES128-GCM-SHA256:ECDHE-RSA-AES256-SHA384:ECDHE-RSA-AES128-SHA256:ECDHE-RSA-AES256-SHA:ECDHE-RSA-AES128-SHA:AES256-GCM-SHA384:AES128-GCM-SHA256:AES256-SHA:AES128-SHA:DHE-RSA-AES128-SHA:DHE-RSA-AES256-SHA:DHE-DSS-AES128-SHA:DHE-DSS-AES256-SHA')
# ('ssl_crl', '')
# ('ssl_crlpath', '')
# ('ssl_fips_mode', 'OFF')
# ('ssl_key', '/rdsdbdata/rds-metadata/server-key.pem')
# ('stored_program_cache', '256')
# ('stored_program_definition_cache', '256')
# ('super_read_only', 'OFF')
# ('sync_binlog', '1')
# ('sync_master_info', '10000')
# ('sync_relay_log', '10000')
# ('sync_relay_log_info', '10000')
# ('sync_source_info', '10000')
# ('system_time_zone', 'UTC')
# ('table_definition_cache', '2000')
# ('table_encryption_privilege_check', 'OFF')
# ('table_open_cache', '4000')
# ('table_open_cache_instances', '16')
# ('tablespace_definition_cache', '256')
# ('temptable_max_mmap', '1073741824')
# ('temptable_max_ram', '1073741824')
# ('temptable_use_mmap', 'ON')
# ('terminology_use_previous', 'BEFORE_8_0_26')
# ('thread_cache_size', '8')
# ('thread_handling', 'one-thread-per-connection')
# ('thread_stack', '262144')
# ('time_zone', 'UTC')
# ('timestamp', '1645045147.670470')
# ('tls_ciphersuites', '')
# ('tls_version', 'TLSv1,TLSv1.1,TLSv1.2,TLSv1.3')
# ('tmp_table_size', '16777216')
# ('tmpdir', '/rdsdbdata/tmp')
# ('transaction_alloc_block_size', '8192')
# ('transaction_allow_batching', 'OFF')
# ('transaction_isolation', 'REPEATABLE-READ')
# ('transaction_prealloc_size', '4096')
# ('transaction_read_only', 'OFF')
# ('transaction_write_set_extraction', 'XXHASH64')
# ('unique_checks', 'ON')
# ('updatable_views_with_limit', 'YES')
# ('use_secondary_engine', 'ON')
# ('version', '8.0.27')
# ('version_comment', 'Source distribution')
# ('version_compile_machine', 'x86_64')
# ('version_compile_os', 'Linux')
# ('version_compile_zlib', '1.2.11')
# ('wait_timeout', '28800')
# ('warning_count', '0')
# ('windowing_use_high_precision', 'ON')

# %%
# sql2 = """
# CREATE TABLE IF NOT EXISTS station (
# address VARCHAR(256),
# banking INTEGER,
# bike_stands INTEGER,
# bonus INTEGER,
# contract_name VARCHAR(256),
# name VARCHAR(256),
# number INTEGER,
# position_lat REAL,
# position_lng REAL,
# status VARCHAR(256)
# )
# """
try:
    res = engine.execute("DROP TABLE IF EXISTS station")
    res = engine.execute(sql2)
    print(res.fetchall())
except Exception as e:
    print(e)
# Out:
# 2022-02-16 20:59:13,351 INFO sqlalchemy.engine.Engine DROP TABLE IF EXISTS station
# 2022-02-16 20:59:13,351 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-16 20:59:13,494 INFO sqlalchemy.engine.Engine COMMIT
# name 'sql2' is not defined

# %%
sql3 = """
CREATE TABLE IF NOT EXISTS available (
number INTEGER,
available_bike_stands INTEGER,
available_bikes INTEGER,
status VARCHAR(256),
last_update INTEGER

)

"""
try:
    res = engine.execute(sql3)
    print(res.fetchall())
except Exception as e:
    print(e)
# Out:
# 2022-02-16 20:59:31,232 INFO sqlalchemy.engine.Engine
# CREATE TABLE IF NOT EXISTS available (
# number INTEGER,
# available_bike_stands INTEGER,
# available_bikes INTEGER,
# status VARCHAR(256),
# last_update INTEGER
#
# )
#
#
# 2022-02-16 20:59:31,234 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-02-16 20:59:31,356 INFO sqlalchemy.engine.Engine COMMIT
# This result object does not return rows. It has been closed automatically.

# %%
import requests
r = requests.get("https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey=0d101d6645f441b34490f9530a0f91c869debe77")
print(r)
r.json()
# Out:
# <Response [200]>
# [{'number': 42,
#   'contract_name': 'dublin',
#   'name': 'SMITHFIELD NORTH',
#   'address': 'Smithfield North',
#   'position': {'lat': 53.349562, 'lng': -6.278198},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 0,
#   'available_bikes': 30,
#   'status': 'OPEN',
#   'last_update': 1645044631000},
#  {'number': 30,
#   'contract_name': 'dublin',
#   'name': 'PARNELL SQUARE NORTH',
#   'address': 'Parnell Square North',
#   'position': {'lat': 53.353462, 'lng': -6.265305},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1645044576000},
#  {'number': 54,
#   'contract_name': 'dublin',
#   'name': 'CLONMEL STREET',
#   'address': 'Clonmel Street',
#   'position': {'lat': 53.336021, 'lng': -6.26298},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 33,
#   'available_bike_stands': 14,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1645044718000},
#  {'number': 108,
#   'contract_name': 'dublin',
#   'name': 'AVONDALE ROAD',
#   'address': 'Avondale Road',
#   'position': {'lat': 53.359405, 'lng': -6.276142},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 35,
#   'available_bike_stands': 19,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1645044957000},
#  {'number': 56,
#   'contract_name': 'dublin',
#   'name': 'MOUNT STREET LOWER',
#   'address': 'Mount Street Lower',
#   'position': {'lat': 53.33796, 'lng': -6.24153},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 25,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1645045056000},
#  {'number': 6,
#   'contract_name': 'dublin',
#   'name': 'CHRISTCHURCH PLACE',
#   'address': 'Christchurch Place',
#   'position': {'lat': 53.343368, 'lng': -6.27012},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 15,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1645044692000},
#  {'number': 18,
#   'contract_name': 'dublin',
#   'name': 'GRANTHAM STREET',
#   'address': 'Grantham Street',
#   'position': {'lat': 53.334123, 'lng': -6.265436},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 5,
#   'available_bikes': 25,
#   'status': 'OPEN',
#   'last_update': 1645045034000},
#  {'number': 32,
#   'contract_name': 'dublin',
#   'name': 'PEARSE STREET',
#   'address': 'Pearse Street',
#   'position': {'lat': 53.344304, 'lng': -6.250427},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 26,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645044983000},
#  {'number': 52,
#   'contract_name': 'dublin',
#   'name': 'YORK STREET EAST',
#   'address': 'York Street East',
#   'position': {'lat': 53.338755, 'lng': -6.262003},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 32,
#   'available_bike_stands': 30,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1645045109000},
#  {'number': 48,
#   'contract_name': 'dublin',
#   'name': 'EXCISE WALK',
#   'address': 'Excise Walk',
#   'position': {'lat': 53.347777, 'lng': -6.244239},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 21,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1645044898000},
#  {'number': 13,
#   'contract_name': 'dublin',
#   'name': 'FITZWILLIAM SQUARE WEST',
#   'address': 'Fitzwilliam Square West',
#   'position': {'lat': 53.336074, 'lng': -6.252825},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1645044574000},
#  {'number': 43,
#   'contract_name': 'dublin',
#   'name': 'PORTOBELLO ROAD',
#   'address': 'Portobello Road',
#   'position': {'lat': 53.330091, 'lng': -6.268044},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 0,
#   'available_bikes': 30,
#   'status': 'OPEN',
#   'last_update': 1645044998000},
#  {'number': 31,
#   'contract_name': 'dublin',
#   'name': 'PARNELL STREET',
#   'address': 'Parnell Street',
#   'position': {'lat': 53.350929, 'lng': -6.265125},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 15,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1645044625000},
#  {'number': 98,
#   'contract_name': 'dublin',
#   'name': 'FREDERICK STREET SOUTH',
#   'address': 'Frederick Street South',
#   'position': {'lat': 53.341515, 'lng': -6.256853},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1645045075000},
#  {'number': 23,
#   'contract_name': 'dublin',
#   'name': 'CUSTOM HOUSE',
#   'address': 'Custom House',
#   'position': {'lat': 53.348279, 'lng': -6.254662},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 5,
#   'available_bikes': 25,
#   'status': 'OPEN',
#   'last_update': 1645044720000},
#  {'number': 106,
#   'contract_name': 'dublin',
#   'name': 'RATHDOWN ROAD',
#   'address': 'Rathdown Road',
#   'position': {'lat': 53.35893, 'lng': -6.280337},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 18,
#   'available_bikes': 22,
#   'status': 'OPEN',
#   'last_update': 1645044654000},
#  {'number': 112,
#   'contract_name': 'dublin',
#   'name': "NORTH CIRCULAR ROAD (O'CONNELL'S)",
#   'address': "North Circular Road (O'Connell's)",
#   'position': {'lat': 53.357841, 'lng': -6.251557},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 14,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1645044861000},
#  {'number': 68,
#   'contract_name': 'dublin',
#   'name': 'HANOVER QUAY',
#   'address': 'Hanover Quay',
#   'position': {'lat': 53.344115, 'lng': -6.237153},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1645045109000},
#  {'number': 74,
#   'contract_name': 'dublin',
#   'name': 'OLIVER BOND STREET',
#   'address': 'Oliver Bond Street',
#   'position': {'lat': 53.343893, 'lng': -6.280531},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 10,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1645044853000},
#  {'number': 87,
#   'contract_name': 'dublin',
#   'name': 'COLLINS BARRACKS MUSEUM',
#   'address': 'Collins Barracks Museum',
#   'position': {'lat': 53.347477, 'lng': -6.28525},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 38,
#   'available_bike_stands': 30,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1645044957000},
#  {'number': 84,
#   'contract_name': 'dublin',
#   'name': 'BROOKFIELD ROAD',
#   'address': 'Brookfield Road',
#   'position': {'lat': 53.339005, 'lng': -6.300217},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 13,
#   'available_bikes': 17,
#   'status': 'OPEN',
#   'last_update': 1645044848000},
#  {'number': 90,
#   'contract_name': 'dublin',
#   'name': 'BENSON STREET',
#   'address': 'Benson Street',
#   'position': {'lat': 53.344153, 'lng': -6.233451},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 38,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1645044733000},
#  {'number': 11,
#   'contract_name': 'dublin',
#   'name': 'EARLSFORT TERRACE',
#   'address': 'Earlsfort Terrace',
#   'position': {'lat': 53.334295, 'lng': -6.258503},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 25,
#   'available_bikes': 5,
#   'status': 'OPEN',
#   'last_update': 1645045139000},
#  {'number': 17,
#   'contract_name': 'dublin',
#   'name': 'GOLDEN LANE',
#   'address': 'Golden Lane',
#   'position': {'lat': 53.340803, 'lng': -6.267732},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 14,
#   'available_bikes': 6,
#   'status': 'OPEN',
#   'last_update': 1645044754000},
#  {'number': 45,
#   'contract_name': 'dublin',
#   'name': 'DEVERELL PLACE',
#   'address': 'Deverell Place',
#   'position': {'lat': 53.351464, 'lng': -6.255265},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 11,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1645044609000},
#  {'number': 114,
#   'contract_name': 'dublin',
#   'name': 'WILTON TERRACE (PARK)',
#   'address': 'Wilton Terrace (Park)',
#   'position': {'lat': 53.333653, 'lng': -6.248345},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1645044578000},
#  {'number': 72,
#   'contract_name': 'dublin',
#   'name': 'JOHN STREET WEST',
#   'address': 'John Street West',
#   'position': {'lat': 53.343105, 'lng': -6.277167},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 31,
#   'available_bike_stands': 29,
#   'available_bikes': 2,
#   'status': 'OPEN',
#   'last_update': 1645044989000},
#  {'number': 63,
#   'contract_name': 'dublin',
#   'name': 'FENIAN STREET',
#   'address': 'Fenian Street',
#   'position': {'lat': 53.341428, 'lng': -6.24672},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 35,
#   'available_bike_stands': 24,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1645044612000},
#  {'number': 113,
#   'contract_name': 'dublin',
#   'name': 'MERRION SQUARE SOUTH',
#   'address': 'Merrion Square South',
#   'position': {'lat': 53.338614, 'lng': -6.248606},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 24,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1645044670000},
#  {'number': 91,
#   'contract_name': 'dublin',
#   'name': 'SOUTH DOCK ROAD',
#   'address': 'South Dock Road',
#   'position': {'lat': 53.341833, 'lng': -6.231291},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 3,
#   'available_bikes': 27,
#   'status': 'OPEN',
#   'last_update': 1645045024000},
#  {'number': 99,
#   'contract_name': 'dublin',
#   'name': 'CITY QUAY',
#   'address': 'City Quay',
#   'position': {'lat': 53.346637, 'lng': -6.246154},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 30,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1645044913000},
#  {'number': 9,
#   'contract_name': 'dublin',
#   'name': 'EXCHEQUER STREET',
#   'address': 'Exchequer Street',
#   'position': {'lat': 53.343034, 'lng': -6.263578},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 24,
#   'available_bike_stands': 6,
#   'available_bikes': 18,
#   'status': 'OPEN',
#   'last_update': 1645045109000},
#  {'number': 67,
#   'contract_name': 'dublin',
#   'name': 'THE POINT',
#   'address': 'The Point',
#   'position': {'lat': 53.346867, 'lng': -6.230852},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 8,
#   'available_bikes': 32,
#   'status': 'OPEN',
#   'last_update': 1645045132000},
#  {'number': 116,
#   'contract_name': 'dublin',
#   'name': 'BROADSTONE',
#   'address': 'Broadstone',
#   'position': {'lat': 53.3547, 'lng': -6.272314},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 10,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1645045027000},
#  {'number': 55,
#   'contract_name': 'dublin',
#   'name': 'HATCH STREET',
#   'address': 'Hatch Street',
#   'position': {'lat': 53.33403, 'lng': -6.260714},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 36,
#   'available_bike_stands': 36,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1645045112000},
#  {'number': 62,
#   'contract_name': 'dublin',
#   'name': 'LIME STREET',
#   'address': 'Lime Street',
#   'position': {'lat': 53.346026, 'lng': -6.243576},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 40,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1645044937000},
#  {'number': 5,
#   'contract_name': 'dublin',
#   'name': 'CHARLEMONT PLACE',
#   'address': 'Charlemont Street',
#   'position': {'lat': 53.330662, 'lng': -6.260177},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 16,
#   'available_bikes': 24,
#   'status': 'OPEN',
#   'last_update': 1645044784000},
#  {'number': 97,
#   'contract_name': 'dublin',
#   'name': 'KILMAINHAM GAOL',
#   'address': 'Kilmainham Gaol',
#   'position': {'lat': 53.342113, 'lng': -6.310015},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 14,
#   'available_bikes': 26,
#   'status': 'OPEN',
#   'last_update': 1645045149000},
#  {'number': 61,
#   'contract_name': 'dublin',
#   'name': 'HARDWICKE PLACE',
#   'address': 'Hardwicke Place',
#   'position': {'lat': 53.357043, 'lng': -6.263232},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 21,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645044741000},
#  {'number': 77,
#   'contract_name': 'dublin',
#   'name': 'WOLFE TONE STREET',
#   'address': 'Wolfe Tone Street',
#   'position': {'lat': 53.348875, 'lng': -6.267459},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 12,
#   'available_bikes': 17,
#   'status': 'OPEN',
#   'last_update': 1645044912000},
#  {'number': 73,
#   'contract_name': 'dublin',
#   'name': 'FRANCIS STREET',
#   'address': 'Francis Street',
#   'position': {'lat': 53.342081, 'lng': -6.275233},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 26,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645044871000},
#  {'number': 4,
#   'contract_name': 'dublin',
#   'name': 'GREEK STREET',
#   'address': 'Greek Street',
#   'position': {'lat': 53.346874, 'lng': -6.272976},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 17,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1645045136000},
#  {'number': 49,
#   'contract_name': 'dublin',
#   'name': 'GUILD STREET',
#   'address': 'Guild Street',
#   'position': {'lat': 53.347932, 'lng': -6.240928},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 19,
#   'available_bikes': 21,
#   'status': 'OPEN',
#   'last_update': 1645045083000},
#  {'number': 19,
#   'contract_name': 'dublin',
#   'name': 'HERBERT PLACE',
#   'address': 'Herbert Place',
#   'position': {'lat': 53.334432, 'lng': -6.245575},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1645044914000},
#  {'number': 7,
#   'contract_name': 'dublin',
#   'name': 'HIGH STREET',
#   'address': 'High Street',
#   'position': {'lat': 53.343565, 'lng': -6.275071},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 19,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1645044858000},
#  {'number': 60,
#   'contract_name': 'dublin',
#   'name': 'NORTH CIRCULAR ROAD',
#   'address': 'North Circular Road',
#   'position': {'lat': 53.359624, 'lng': -6.260348},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 5,
#   'available_bikes': 25,
#   'status': 'OPEN',
#   'last_update': 1645045116000},
#  {'number': 102,
#   'contract_name': 'dublin',
#   'name': 'WESTERN WAY',
#   'address': 'Western Way',
#   'position': {'lat': 53.354929, 'lng': -6.269425},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 26,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1645044710000},
#  {'number': 38,
#   'contract_name': 'dublin',
#   'name': 'TALBOT STREET',
#   'address': 'Talbot Street',
#   'position': {'lat': 53.350974, 'lng': -6.25294},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 14,
#   'available_bikes': 26,
#   'status': 'OPEN',
#   'last_update': 1645044948000},
#  {'number': 53,
#   'contract_name': 'dublin',
#   'name': 'NEWMAN HOUSE',
#   'address': 'Newman House',
#   'position': {'lat': 53.337132, 'lng': -6.26059},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 36,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645045121000},
#  {'number': 58,
#   'contract_name': 'dublin',
#   'name': "SIR PATRICK DUN'S",
#   'address': "Sir Patrick's Dun",
#   'position': {'lat': 53.339218, 'lng': -6.240642},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 25,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1645045021000},
#  {'number': 66,
#   'contract_name': 'dublin',
#   'name': 'NEW CENTRAL BANK',
#   'address': 'New Central Bank',
#   'position': {'lat': 53.347122, 'lng': -6.234749},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 18,
#   'available_bikes': 22,
#   'status': 'OPEN',
#   'last_update': 1645044953000},
#  {'number': 104,
#   'contract_name': 'dublin',
#   'name': 'GRANGEGORMAN LOWER (CENTRAL)',
#   'address': 'Grangegorman Lower (Central)',
#   'position': {'lat': 53.355173, 'lng': -6.278424},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 32,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1645044692000},
#  {'number': 101,
#   'contract_name': 'dublin',
#   'name': 'KING STREET NORTH',
#   'address': 'King Street North',
#   'position': {'lat': 53.350291, 'lng': -6.273507},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 12,
#   'available_bikes': 18,
#   'status': 'OPEN',
#   'last_update': 1645044854000},
#  {'number': 115,
#   'contract_name': 'dublin',
#   'name': 'KILLARNEY STREET',
#   'address': 'Killarney Street',
#   'position': {'lat': 53.354845, 'lng': -6.247579},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 8,
#   'available_bikes': 22,
#   'status': 'OPEN',
#   'last_update': 1645044893000},
#  {'number': 47,
#   'contract_name': 'dublin',
#   'name': 'HERBERT STREET',
#   'address': 'Herbert Street',
#   'position': {'lat': 53.335742, 'lng': -6.24551},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1645045111000},
#  {'number': 117,
#   'contract_name': 'dublin',
#   'name': 'HANOVER QUAY EAST',
#   'address': 'Hanover Quay East',
#   'position': {'lat': 53.343653, 'lng': -6.231755},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 29,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1645044960000},
#  {'number': 8,
#   'contract_name': 'dublin',
#   'name': 'CUSTOM HOUSE QUAY',
#   'address': 'Custom House Quay',
#   'position': {'lat': 53.347884, 'lng': -6.248048},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 10,
#   'available_bikes': 20,
#   'status': 'OPEN',
#   'last_update': 1645044814000},
#  {'number': 27,
#   'contract_name': 'dublin',
#   'name': 'MOLESWORTH STREET',
#   'address': 'Molesworth Street',
#   'position': {'lat': 53.341288, 'lng': -6.258117},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 20,
#   'available_bikes': 0,
#   'status': 'OPEN',
#   'last_update': 1645044766000},
#  {'number': 16,
#   'contract_name': 'dublin',
#   'name': 'GEORGES QUAY',
#   'address': 'Georges Quay',
#   'position': {'lat': 53.347508, 'lng': -6.252192},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 5,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1645045145000},
#  {'number': 96,
#   'contract_name': 'dublin',
#   'name': 'KILMAINHAM LANE',
#   'address': 'Kilmainham Lane',
#   'position': {'lat': 53.341805, 'lng': -6.305085},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 11,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1645044608000},
#  {'number': 82,
#   'contract_name': 'dublin',
#   'name': 'MOUNT BROWN',
#   'address': 'Mount Brown',
#   'position': {'lat': 53.341645, 'lng': -6.29719},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 22,
#   'available_bike_stands': 8,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1645045154000},
#  {'number': 76,
#   'contract_name': 'dublin',
#   'name': 'MARKET STREET SOUTH',
#   'address': 'Market Street South',
#   'position': {'lat': 53.342296, 'lng': -6.287661},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 38,
#   'available_bike_stands': 24,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1645044828000},
#  {'number': 71,
#   'contract_name': 'dublin',
#   'name': 'KEVIN STREET',
#   'address': 'Kevin Street',
#   'position': {'lat': 53.337757, 'lng': -6.267699},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 36,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645044555000},
#  {'number': 79,
#   'contract_name': 'dublin',
#   'name': 'ECCLES STREET EAST',
#   'address': 'Eccles Street East',
#   'position': {'lat': 53.358115, 'lng': -6.265601},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 27,
#   'available_bike_stands': 12,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1645045061000},
#  {'number': 69,
#   'contract_name': 'dublin',
#   'name': 'GRAND CANAL DOCK',
#   'address': 'Grand Canal Dock',
#   'position': {'lat': 53.342638, 'lng': -6.238695},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 17,
#   'available_bikes': 23,
#   'status': 'OPEN',
#   'last_update': 1645044858000},
#  {'number': 25,
#   'contract_name': 'dublin',
#   'name': 'MERRION SQUARE EAST',
#   'address': 'Merrion Square East',
#   'position': {'lat': 53.339434, 'lng': -6.246548},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 29,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1645045099000},
#  {'number': 51,
#   'contract_name': 'dublin',
#   'name': 'YORK STREET WEST',
#   'address': 'York Street West',
#   'position': {'lat': 53.339334, 'lng': -6.264699},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 36,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645045002000},
#  {'number': 37,
#   'contract_name': 'dublin',
#   'name': "ST. STEPHEN'S GREEN SOUTH",
#   'address': "St. Stephen's Green South",
#   'position': {'lat': 53.337494, 'lng': -6.26199},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 23,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1645045104000},
#  {'number': 59,
#   'contract_name': 'dublin',
#   'name': 'DENMARK STREET GREAT',
#   'address': 'Denmark Street Great',
#   'position': {'lat': 53.35561, 'lng': -6.261397},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 12,
#   'available_bikes': 7,
#   'status': 'OPEN',
#   'last_update': 1645045003000},
#  {'number': 95,
#   'contract_name': 'dublin',
#   'name': 'ROYAL HOSPITAL',
#   'address': 'Royal Hospital',
#   'position': {'lat': 53.343897, 'lng': -6.29706},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 30,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1645045058000},
#  {'number': 94,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON STATION (CAR PARK)',
#   'address': 'Heuston Station (Car Park)',
#   'position': {'lat': 53.346985, 'lng': -6.297804},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1645044573000},
#  {'number': 105,
#   'contract_name': 'dublin',
#   'name': 'GRANGEGORMAN LOWER (NORTH)',
#   'address': 'Grangegorman Lower (North)',
#   'position': {'lat': 53.355954, 'lng': -6.278378},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 36,
#   'available_bike_stands': 18,
#   'available_bikes': 18,
#   'status': 'OPEN',
#   'last_update': 1645045150000},
#  {'number': 36,
#   'contract_name': 'dublin',
#   'name': "ST. STEPHEN'S GREEN EAST",
#   'address': "St. Stephen's Green East",
#   'position': {'lat': 53.337824, 'lng': -6.256035},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 29,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1645044639000},
#  {'number': 93,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON STATION (CENTRAL)',
#   'address': 'Heuston Station (Central)',
#   'position': {'lat': 53.346603, 'lng': -6.296924},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 36,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645044983000},
#  {'number': 22,
#   'contract_name': 'dublin',
#   'name': 'TOWNSEND STREET',
#   'address': 'Townsend Street',
#   'position': {'lat': 53.345922, 'lng': -6.254614},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 3,
#   'available_bikes': 17,
#   'status': 'OPEN',
#   'last_update': 1645044729000},
#  {'number': 50,
#   'contract_name': 'dublin',
#   'name': 'GEORGES LANE',
#   'address': "George's Lane",
#   'position': {'lat': 53.35023, 'lng': -6.279696},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 15,
#   'available_bikes': 25,
#   'status': 'OPEN',
#   'last_update': 1645044976000},
#  {'number': 110,
#   'contract_name': 'dublin',
#   'name': 'PHIBSBOROUGH ROAD',
#   'address': 'Phibsborough Road',
#   'position': {'lat': 53.356307, 'lng': -6.273717},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 17,
#   'available_bikes': 23,
#   'status': 'OPEN',
#   'last_update': 1645044915000},
#  {'number': 12,
#   'contract_name': 'dublin',
#   'name': 'ECCLES STREET',
#   'address': 'Eccles Street',
#   'position': {'lat': 53.359246, 'lng': -6.269779},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 5,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1645044853000},
#  {'number': 34,
#   'contract_name': 'dublin',
#   'name': 'PORTOBELLO HARBOUR',
#   'address': 'Portobello Harbour',
#   'position': {'lat': 53.330362, 'lng': -6.265163},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 1,
#   'available_bikes': 29,
#   'status': 'OPEN',
#   'last_update': 1645045111000},
#  {'number': 78,
#   'contract_name': 'dublin',
#   'name': 'MATER HOSPITAL',
#   'address': 'Mater Hospital',
#   'position': {'lat': 53.359967, 'lng': -6.264828},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1645044761000},
#  {'number': 2,
#   'contract_name': 'dublin',
#   'name': 'BLESSINGTON STREET',
#   'address': 'Blessington Street',
#   'position': {'lat': 53.356769, 'lng': -6.26814},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 10,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1645044732000},
#  {'number': 75,
#   'contract_name': 'dublin',
#   'name': 'JAMES STREET',
#   'address': 'James Street',
#   'position': {'lat': 53.343456, 'lng': -6.287409},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 4,
#   'available_bikes': 36,
#   'status': 'OPEN',
#   'last_update': 1645045060000},
#  {'number': 111,
#   'contract_name': 'dublin',
#   'name': 'MOUNTJOY SQUARE EAST',
#   'address': 'Mountjoy Square East',
#   'position': {'lat': 53.356717, 'lng': -6.256359},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 31,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1645044590000},
#  {'number': 26,
#   'contract_name': 'dublin',
#   'name': 'MERRION SQUARE WEST',
#   'address': 'Merrion Square West',
#   'position': {'lat': 53.339764, 'lng': -6.251988},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 19,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1645045086000},
#  {'number': 65,
#   'contract_name': 'dublin',
#   'name': 'CONVENTION CENTRE',
#   'address': 'Convention Centre',
#   'position': {'lat': 53.34744, 'lng': -6.238523},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 37,
#   'available_bikes': 3,
#   'status': 'OPEN',
#   'last_update': 1645044791000},
#  {'number': 15,
#   'contract_name': 'dublin',
#   'name': 'HARDWICKE STREET',
#   'address': 'Hardwicke Street',
#   'position': {'lat': 53.355473, 'lng': -6.264423},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 2,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1645045051000},
#  {'number': 86,
#   'contract_name': 'dublin',
#   'name': 'PARKGATE STREET',
#   'address': 'Parkgate Street',
#   'position': {'lat': 53.347972, 'lng': -6.291804},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 38,
#   'available_bike_stands': 22,
#   'available_bikes': 16,
#   'status': 'OPEN',
#   'last_update': 1645044677000},
#  {'number': 10,
#   'contract_name': 'dublin',
#   'name': 'DAME STREET',
#   'address': 'Dame Street',
#   'position': {'lat': 53.344007, 'lng': -6.266802},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 16,
#   'available_bike_stands': 7,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1645044974000},
#  {'number': 100,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON BRIDGE (SOUTH)',
#   'address': 'Heuston Bridge (South)',
#   'position': {'lat': 53.347106, 'lng': -6.292041},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 25,
#   'available_bike_stands': 0,
#   'available_bikes': 25,
#   'status': 'OPEN',
#   'last_update': 1645044642000},
#  {'number': 24,
#   'contract_name': 'dublin',
#   'name': 'CATHAL BRUGHA STREET',
#   'address': 'Cathal Brugha Street',
#   'position': {'lat': 53.352149, 'lng': -6.260533},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 2,
#   'available_bikes': 18,
#   'status': 'OPEN',
#   'last_update': 1645044812000},
#  {'number': 64,
#   'contract_name': 'dublin',
#   'name': 'SANDWITH STREET',
#   'address': 'Sandwith Street',
#   'position': {'lat': 53.345203, 'lng': -6.247163},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 29,
#   'available_bikes': 11,
#   'status': 'OPEN',
#   'last_update': 1645044830000},
#  {'number': 109,
#   'contract_name': 'dublin',
#   'name': 'BUCKINGHAM STREET LOWER',
#   'address': 'Buckingham Street Lower',
#   'position': {'lat': 53.353331, 'lng': -6.249319},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 10,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1645045027000},
#  {'number': 85,
#   'contract_name': 'dublin',
#   'name': 'ROTHE ABBEY',
#   'address': 'Rothe Abbey',
#   'position': {'lat': 53.338776, 'lng': -6.30395},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 35,
#   'available_bike_stands': 17,
#   'available_bikes': 18,
#   'status': 'OPEN',
#   'last_update': 1645044958000},
#  {'number': 107,
#   'contract_name': 'dublin',
#   'name': 'CHARLEVILLE ROAD',
#   'address': 'Charleville Road',
#   'position': {'lat': 53.359157, 'lng': -6.281866},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 15,
#   'available_bikes': 25,
#   'status': 'OPEN',
#   'last_update': 1645044768000},
#  {'number': 33,
#   'contract_name': 'dublin',
#   'name': "PRINCES STREET / O'CONNELL STREET",
#   'address': "Princes Street / O'Connell Street",
#   'position': {'lat': 53.349013, 'lng': -6.260311},
#   'banking': True,
#   'bonus': False,
#   'bike_stands': 23,
#   'available_bike_stands': 10,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1645044880000},
#  {'number': 44,
#   'contract_name': 'dublin',
#   'name': 'UPPER SHERRARD STREET',
#   'address': 'Upper Sherrard Street',
#   'position': {'lat': 53.358437, 'lng': -6.260641},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 16,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1645045079000},
#  {'number': 89,
#   'contract_name': 'dublin',
#   'name': 'FITZWILLIAM SQUARE EAST',
#   'address': 'Fitzwilliam Square East',
#   'position': {'lat': 53.335211, 'lng': -6.2509},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 39,
#   'available_bikes': 1,
#   'status': 'OPEN',
#   'last_update': 1645044722000},
#  {'number': 57,
#   'contract_name': 'dublin',
#   'name': 'GRATTAN STREET',
#   'address': 'Grattan Street',
#   'position': {'lat': 53.339629, 'lng': -6.243778},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 23,
#   'available_bike_stands': 15,
#   'available_bikes': 8,
#   'status': 'OPEN',
#   'last_update': 1645045083000},
#  {'number': 80,
#   'contract_name': 'dublin',
#   'name': 'ST JAMES HOSPITAL (LUAS)',
#   'address': 'St James Hospital (Luas)',
#   'position': {'lat': 53.341359, 'lng': -6.292951},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 30,
#   'available_bikes': 10,
#   'status': 'OPEN',
#   'last_update': 1645044912000},
#  {'number': 41,
#   'contract_name': 'dublin',
#   'name': 'HARCOURT TERRACE',
#   'address': 'Harcourt Terrace',
#   'position': {'lat': 53.332763, 'lng': -6.257942},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 8,
#   'available_bikes': 12,
#   'status': 'OPEN',
#   'last_update': 1645045098000},
#  {'number': 3,
#   'contract_name': 'dublin',
#   'name': 'BOLTON STREET',
#   'address': 'Bolton Street',
#   'position': {'lat': 53.351182, 'lng': -6.269859},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 8,
#   'available_bikes': 12,
#   'status': 'OPEN',
#   'last_update': 1645044703000},
#  {'number': 40,
#   'contract_name': 'dublin',
#   'name': 'JERVIS STREET',
#   'address': 'Jervis Street',
#   'position': {'lat': 53.3483, 'lng': -6.266651},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 21,
#   'available_bike_stands': 2,
#   'available_bikes': 19,
#   'status': 'OPEN',
#   'last_update': 1645045073000},
#  {'number': 29,
#   'contract_name': 'dublin',
#   'name': 'ORMOND QUAY UPPER',
#   'address': 'Ormond Quay Upper',
#   'position': {'lat': 53.346057, 'lng': -6.268001},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 29,
#   'available_bike_stands': 16,
#   'available_bikes': 13,
#   'status': 'OPEN',
#   'last_update': 1645044849000},
#  {'number': 103,
#   'contract_name': 'dublin',
#   'name': 'GRANGEGORMAN LOWER (SOUTH)',
#   'address': 'Grangegorman Lower (South)',
#   'position': {'lat': 53.354663, 'lng': -6.278681},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 25,
#   'available_bikes': 15,
#   'status': 'OPEN',
#   'last_update': 1645044610000},
#  {'number': 28,
#   'contract_name': 'dublin',
#   'name': 'MOUNTJOY SQUARE WEST',
#   'address': 'Mountjoy Square West',
#   'position': {'lat': 53.356299, 'lng': -6.258586},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 8,
#   'available_bikes': 22,
#   'status': 'OPEN',
#   'last_update': 1645044721000},
#  {'number': 39,
#   'contract_name': 'dublin',
#   'name': 'WILTON TERRACE',
#   'address': 'Wilton Terrace',
#   'position': {'lat': 53.332383, 'lng': -6.252717},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 20,
#   'available_bike_stands': 16,
#   'available_bikes': 4,
#   'status': 'OPEN',
#   'last_update': 1645044709000},
#  {'number': 83,
#   'contract_name': 'dublin',
#   'name': 'EMMET ROAD',
#   'address': 'Emmet Road',
#   'position': {'lat': 53.340714, 'lng': -6.308191},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 17,
#   'available_bikes': 23,
#   'status': 'OPEN',
#   'last_update': 1645044934000},
#  {'number': 92,
#   'contract_name': 'dublin',
#   'name': 'HEUSTON BRIDGE (NORTH)',
#   'address': 'Heuston Bridge (North)',
#   'position': {'lat': 53.347802, 'lng': -6.292432},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 40,
#   'available_bike_stands': 26,
#   'available_bikes': 14,
#   'status': 'OPEN',
#   'last_update': 1645045117000},
#  {'number': 21,
#   'contract_name': 'dublin',
#   'name': 'LEINSTER STREET SOUTH',
#   'address': 'Leinster Street South',
#   'position': {'lat': 53.34218, 'lng': -6.254485},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 21,
#   'available_bikes': 9,
#   'status': 'OPEN',
#   'last_update': 1645044721000},
#  {'number': 88,
#   'contract_name': 'dublin',
#   'name': 'BLACKHALL PLACE',
#   'address': 'Blackhall Place',
#   'position': {'lat': 53.3488, 'lng': -6.281637},
#   'banking': False,
#   'bonus': False,
#   'bike_stands': 30,
#   'available_bike_stands': 6,
#   'available_bikes': 24,
#   'status': 'OPEN',
#   'last_update': 1645045077000}]

# %%
import traceback
import datetime
import time


def write_to_file(text):
    with open ("data/bikes_{}".format(now).replace(" ", "_", "w")) as f:
        f.write(r.text)

def write_to_db(text):
    stations = json.loads(text)
    for station in stations:
        vals = [station.get("number"), station.get("available_bikes"),
                station.get("available_bike_stands"), station.get("last_update")]
        engine.execute("insert into availability values(%s,%s,%s,%s)", vals)

    
    return

def main():
    while True:
        try:
#                 now = datetime.datetime.now()
            r = requests.get("https://api.jcdecaux.com/vls/v1/stations?contract=dublin&apiKey=0d101d6645f441b34490f9530a0f91c869debe77")
#                 print(r,now)
#                 write_to_file(r.text)
            write_to_db(r.text)
            time.sleep(5*60)
        except:
            print(traceback.format_exc())
#                 if engine is None:
    return

if __name__ == '__main__':
    main()
# Out:
# 2022-02-16 20:59:42,056 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:42,056 INFO sqlalchemy.engine.Engine [raw sql] (42, 30, 0, 1645044631000)
# 2022-02-16 20:59:42,177 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:42,432 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:42,432 INFO sqlalchemy.engine.Engine [raw sql] (30, 1, 19, 1645044576000)
# 2022-02-16 20:59:42,546 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:42,793 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:42,796 INFO sqlalchemy.engine.Engine [raw sql] (54, 19, 14, 1645044718000)
# 2022-02-16 20:59:42,916 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:43,155 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:43,160 INFO sqlalchemy.engine.Engine [raw sql] (108, 16, 19, 1645044957000)
# 2022-02-16 20:59:43,276 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:43,504 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:43,519 INFO sqlalchemy.engine.Engine [raw sql] (56, 15, 25, 1645045056000)
# 2022-02-16 20:59:43,627 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:43,869 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:43,886 INFO sqlalchemy.engine.Engine [raw sql] (6, 5, 15, 1645044692000)
# 2022-02-16 20:59:44,002 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:44,249 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:44,250 INFO sqlalchemy.engine.Engine [raw sql] (18, 25, 5, 1645045034000)
# 2022-02-16 20:59:44,360 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:44,605 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:44,605 INFO sqlalchemy.engine.Engine [raw sql] (32, 4, 26, 1645044983000)
# 2022-02-16 20:59:44,725 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:44,974 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:44,974 INFO sqlalchemy.engine.Engine [raw sql] (52, 2, 30, 1645045109000)
# 2022-02-16 20:59:45,091 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:45,335 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:45,335 INFO sqlalchemy.engine.Engine [raw sql] (48, 19, 21, 1645044898000)
# 2022-02-16 20:59:45,473 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:45,717 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:45,717 INFO sqlalchemy.engine.Engine [raw sql] (13, 7, 23, 1645044574000)
# 2022-02-16 20:59:45,838 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:46,071 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:46,071 INFO sqlalchemy.engine.Engine [raw sql] (43, 30, 0, 1645044998000)
# 2022-02-16 20:59:46,509 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:46,754 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:46,754 INFO sqlalchemy.engine.Engine [raw sql] (31, 5, 15, 1645044625000)
# 2022-02-16 20:59:46,874 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:47,119 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:47,119 INFO sqlalchemy.engine.Engine [raw sql] (98, 2, 38, 1645045075000)
# 2022-02-16 20:59:47,248 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:47,492 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:47,495 INFO sqlalchemy.engine.Engine [raw sql] (23, 25, 5, 1645044720000)
# 2022-02-16 20:59:47,613 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:47,853 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:47,856 INFO sqlalchemy.engine.Engine [raw sql] (106, 22, 18, 1645044654000)
# 2022-02-16 20:59:47,962 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:48,219 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:48,222 INFO sqlalchemy.engine.Engine [raw sql] (112, 16, 14, 1645044861000)
# 2022-02-16 20:59:48,341 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:48,576 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:48,576 INFO sqlalchemy.engine.Engine [raw sql] (68, 2, 38, 1645045109000)
# 2022-02-16 20:59:48,703 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:48,937 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:48,937 INFO sqlalchemy.engine.Engine [raw sql] (74, 20, 10, 1645044853000)
# 2022-02-16 20:59:49,055 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:49,301 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:49,301 INFO sqlalchemy.engine.Engine [raw sql] (87, 8, 30, 1645044957000)
# 2022-02-16 20:59:49,420 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:49,665 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:49,665 INFO sqlalchemy.engine.Engine [raw sql] (84, 17, 13, 1645044848000)
# 2022-02-16 20:59:49,791 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:50,038 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:50,038 INFO sqlalchemy.engine.Engine [raw sql] (90, 2, 38, 1645044733000)
# 2022-02-16 20:59:50,154 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:50,395 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:50,395 INFO sqlalchemy.engine.Engine [raw sql] (11, 5, 25, 1645045139000)
# 2022-02-16 20:59:50,519 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:50,770 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:50,770 INFO sqlalchemy.engine.Engine [raw sql] (17, 6, 14, 1645044754000)
# 2022-02-16 20:59:50,892 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:51,148 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:51,154 INFO sqlalchemy.engine.Engine [raw sql] (45, 19, 11, 1645044609000)
# 2022-02-16 20:59:51,281 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:51,510 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:51,510 INFO sqlalchemy.engine.Engine [raw sql] (114, 0, 40, 1645044578000)
# 2022-02-16 20:59:51,635 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:51,878 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:51,878 INFO sqlalchemy.engine.Engine [raw sql] (72, 2, 29, 1645044989000)
# 2022-02-16 20:59:51,999 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:52,247 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:52,247 INFO sqlalchemy.engine.Engine [raw sql] (63, 11, 24, 1645044612000)
# 2022-02-16 20:59:52,370 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:52,609 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:52,612 INFO sqlalchemy.engine.Engine [raw sql] (113, 16, 24, 1645044670000)
# 2022-02-16 20:59:52,731 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:52,966 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:52,966 INFO sqlalchemy.engine.Engine [raw sql] (91, 27, 3, 1645045024000)
# 2022-02-16 20:59:53,082 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:53,329 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:53,329 INFO sqlalchemy.engine.Engine [raw sql] (99, 0, 30, 1645044913000)
# 2022-02-16 20:59:53,448 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:53,695 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:53,695 INFO sqlalchemy.engine.Engine [raw sql] (9, 18, 6, 1645045109000)
# 2022-02-16 20:59:53,814 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:54,047 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:54,063 INFO sqlalchemy.engine.Engine [raw sql] (67, 32, 8, 1645045132000)
# 2022-02-16 20:59:54,181 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:54,423 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:54,425 INFO sqlalchemy.engine.Engine [raw sql] (116, 20, 10, 1645045027000)
# 2022-02-16 20:59:54,549 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:54,794 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:54,794 INFO sqlalchemy.engine.Engine [raw sql] (55, 0, 36, 1645045112000)
# 2022-02-16 20:59:54,905 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:55,145 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:55,160 INFO sqlalchemy.engine.Engine [raw sql] (62, 0, 40, 1645044937000)
# 2022-02-16 20:59:55,282 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:55,521 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:55,521 INFO sqlalchemy.engine.Engine [raw sql] (5, 24, 16, 1645044784000)
# 2022-02-16 20:59:55,647 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:55,887 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:55,890 INFO sqlalchemy.engine.Engine [raw sql] (97, 26, 14, 1645045149000)
# 2022-02-16 20:59:56,015 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:56,247 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:56,247 INFO sqlalchemy.engine.Engine [raw sql] (61, 4, 21, 1645044741000)
# 2022-02-16 20:59:56,377 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:56,622 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:56,622 INFO sqlalchemy.engine.Engine [raw sql] (77, 17, 12, 1645044912000)
# 2022-02-16 20:59:56,744 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:56,981 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:56,982 INFO sqlalchemy.engine.Engine [raw sql] (73, 4, 26, 1645044871000)
# 2022-02-16 20:59:57,101 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:57,338 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:57,346 INFO sqlalchemy.engine.Engine [raw sql] (4, 3, 17, 1645045136000)
# 2022-02-16 20:59:57,462 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:57,712 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:57,712 INFO sqlalchemy.engine.Engine [raw sql] (49, 21, 19, 1645045083000)
# 2022-02-16 20:59:57,828 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:58,085 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:58,086 INFO sqlalchemy.engine.Engine [raw sql] (19, 1, 29, 1645044914000)
# 2022-02-16 20:59:58,198 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:58,444 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:58,444 INFO sqlalchemy.engine.Engine [raw sql] (7, 10, 19, 1645044858000)
# 2022-02-16 20:59:58,575 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:58,821 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:58,827 INFO sqlalchemy.engine.Engine [raw sql] (60, 25, 5, 1645045116000)
# 2022-02-16 20:59:58,939 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:59,186 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:59,191 INFO sqlalchemy.engine.Engine [raw sql] (102, 14, 26, 1645044710000)
# 2022-02-16 20:59:59,312 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:59,552 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:59,552 INFO sqlalchemy.engine.Engine [raw sql] (38, 26, 14, 1645044948000)
# 2022-02-16 20:59:59,683 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 20:59:59,927 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 20:59:59,931 INFO sqlalchemy.engine.Engine [raw sql] (53, 4, 36, 1645045121000)
# 2022-02-16 21:00:00,042 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:00,292 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:00,293 INFO sqlalchemy.engine.Engine [raw sql] (58, 15, 25, 1645045021000)
# 2022-02-16 21:00:00,409 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:00,654 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:00,654 INFO sqlalchemy.engine.Engine [raw sql] (66, 22, 18, 1645044953000)
# 2022-02-16 21:00:00,772 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:01,325 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:01,329 INFO sqlalchemy.engine.Engine [raw sql] (104, 8, 32, 1645044692000)
# 2022-02-16 21:00:01,452 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:01,798 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:01,798 INFO sqlalchemy.engine.Engine [raw sql] (101, 18, 12, 1645044854000)
# 2022-02-16 21:00:01,916 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:02,298 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:02,298 INFO sqlalchemy.engine.Engine [raw sql] (115, 22, 8, 1645044893000)
# 2022-02-16 21:00:02,422 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:02,668 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:02,668 INFO sqlalchemy.engine.Engine [raw sql] (47, 3, 37, 1645045111000)
# 2022-02-16 21:00:02,797 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:03,203 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:03,203 INFO sqlalchemy.engine.Engine [raw sql] (117, 11, 29, 1645044960000)
# 2022-02-16 21:00:03,324 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:03,570 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:03,570 INFO sqlalchemy.engine.Engine [raw sql] (8, 20, 10, 1645044814000)
# 2022-02-16 21:00:03,688 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:03,946 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:03,946 INFO sqlalchemy.engine.Engine [raw sql] (27, 0, 20, 1645044766000)
# 2022-02-16 21:00:04,077 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:04,317 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:04,317 INFO sqlalchemy.engine.Engine [raw sql] (16, 15, 5, 1645045145000)
# 2022-02-16 21:00:04,438 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:04,696 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:04,696 INFO sqlalchemy.engine.Engine [raw sql] (96, 19, 11, 1645044608000)
# 2022-02-16 21:00:04,817 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:05,049 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:05,049 INFO sqlalchemy.engine.Engine [raw sql] (82, 14, 8, 1645045154000)
# 2022-02-16 21:00:05,168 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:05,415 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:05,415 INFO sqlalchemy.engine.Engine [raw sql] (76, 14, 24, 1645044828000)
# 2022-02-16 21:00:05,539 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:05,780 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:05,795 INFO sqlalchemy.engine.Engine [raw sql] (71, 4, 36, 1645044555000)
# 2022-02-16 21:00:05,905 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:06,144 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:06,160 INFO sqlalchemy.engine.Engine [raw sql] (79, 15, 12, 1645045061000)
# 2022-02-16 21:00:06,265 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:06,520 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:06,520 INFO sqlalchemy.engine.Engine [raw sql] (69, 23, 17, 1645044858000)
# 2022-02-16 21:00:06,635 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:06,870 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:06,886 INFO sqlalchemy.engine.Engine [raw sql] (25, 1, 29, 1645045099000)
# 2022-02-16 21:00:07,001 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:07,243 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:07,243 INFO sqlalchemy.engine.Engine [raw sql] (51, 4, 36, 1645045002000)
# 2022-02-16 21:00:07,357 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:07,625 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:07,625 INFO sqlalchemy.engine.Engine [raw sql] (37, 7, 23, 1645045104000)
# 2022-02-16 21:00:07,742 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:07,984 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:07,999 INFO sqlalchemy.engine.Engine [raw sql] (59, 7, 12, 1645045003000)
# 2022-02-16 21:00:08,115 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:08,360 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:08,360 INFO sqlalchemy.engine.Engine [raw sql] (95, 10, 30, 1645045058000)
# 2022-02-16 21:00:08,481 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:08,723 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:08,723 INFO sqlalchemy.engine.Engine [raw sql] (94, 3, 37, 1645044573000)
# 2022-02-16 21:00:08,852 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:09,093 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:09,099 INFO sqlalchemy.engine.Engine [raw sql] (105, 18, 18, 1645045150000)
# 2022-02-16 21:00:09,216 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:09,460 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:09,460 INFO sqlalchemy.engine.Engine [raw sql] (36, 11, 29, 1645044639000)
# 2022-02-16 21:00:09,571 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:09,815 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:09,815 INFO sqlalchemy.engine.Engine [raw sql] (93, 4, 36, 1645044983000)
# 2022-02-16 21:00:09,948 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:10,199 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:10,200 INFO sqlalchemy.engine.Engine [raw sql] (22, 17, 3, 1645044729000)
# 2022-02-16 21:00:10,314 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:10,565 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:10,567 INFO sqlalchemy.engine.Engine [raw sql] (50, 25, 15, 1645044976000)
# 2022-02-16 21:00:10,679 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:10,929 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:10,930 INFO sqlalchemy.engine.Engine [raw sql] (110, 23, 17, 1645044915000)
# 2022-02-16 21:00:11,044 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:11,279 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:11,296 INFO sqlalchemy.engine.Engine [raw sql] (12, 15, 5, 1645044853000)
# 2022-02-16 21:00:11,402 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:11,654 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:11,654 INFO sqlalchemy.engine.Engine [raw sql] (34, 29, 1, 1645045111000)
# 2022-02-16 21:00:11,771 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:12,013 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:12,013 INFO sqlalchemy.engine.Engine [raw sql] (78, 3, 37, 1645044761000)
# 2022-02-16 21:00:12,130 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:12,385 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:12,385 INFO sqlalchemy.engine.Engine [raw sql] (2, 10, 10, 1645044732000)
# 2022-02-16 21:00:12,509 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:12,749 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:12,749 INFO sqlalchemy.engine.Engine [raw sql] (75, 36, 4, 1645045060000)
# 2022-02-16 21:00:12,860 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:13,113 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:13,113 INFO sqlalchemy.engine.Engine [raw sql] (111, 9, 31, 1645044590000)
# 2022-02-16 21:00:13,228 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:13,474 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:13,474 INFO sqlalchemy.engine.Engine [raw sql] (26, 1, 19, 1645045086000)
# 2022-02-16 21:00:13,606 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:13,854 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:13,855 INFO sqlalchemy.engine.Engine [raw sql] (65, 3, 37, 1645044791000)
# 2022-02-16 21:00:13,977 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:14,209 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:14,209 INFO sqlalchemy.engine.Engine [raw sql] (15, 14, 2, 1645045051000)
# 2022-02-16 21:00:14,341 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:14,575 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:14,575 INFO sqlalchemy.engine.Engine [raw sql] (86, 16, 22, 1645044677000)
# 2022-02-16 21:00:14,692 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:14,957 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:14,957 INFO sqlalchemy.engine.Engine [raw sql] (10, 9, 7, 1645044974000)
# 2022-02-16 21:00:15,078 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:15,308 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:15,324 INFO sqlalchemy.engine.Engine [raw sql] (100, 25, 0, 1645044642000)
# 2022-02-16 21:00:15,445 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:15,683 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:15,683 INFO sqlalchemy.engine.Engine [raw sql] (24, 18, 2, 1645044812000)
# 2022-02-16 21:00:15,807 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:16,051 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:16,051 INFO sqlalchemy.engine.Engine [raw sql] (64, 11, 29, 1645044830000)
# 2022-02-16 21:00:16,174 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:16,409 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:16,409 INFO sqlalchemy.engine.Engine [raw sql] (109, 19, 10, 1645045027000)
# 2022-02-16 21:00:16,524 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:16,775 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:16,775 INFO sqlalchemy.engine.Engine [raw sql] (85, 18, 17, 1645044958000)
# 2022-02-16 21:00:16,889 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:17,135 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:17,135 INFO sqlalchemy.engine.Engine [raw sql] (107, 25, 15, 1645044768000)
# 2022-02-16 21:00:17,254 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:17,503 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:17,504 INFO sqlalchemy.engine.Engine [raw sql] (33, 13, 10, 1645044880000)
# 2022-02-16 21:00:17,623 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:17,854 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:17,854 INFO sqlalchemy.engine.Engine [raw sql] (44, 14, 16, 1645045079000)
# 2022-02-16 21:00:17,989 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:18,234 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:18,237 INFO sqlalchemy.engine.Engine [raw sql] (89, 1, 39, 1645044722000)
# 2022-02-16 21:00:18,356 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:18,590 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:18,590 INFO sqlalchemy.engine.Engine [raw sql] (57, 8, 15, 1645045083000)
# 2022-02-16 21:00:18,722 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:18,967 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:18,969 INFO sqlalchemy.engine.Engine [raw sql] (80, 10, 30, 1645044912000)
# 2022-02-16 21:00:19,089 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:19,329 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:19,329 INFO sqlalchemy.engine.Engine [raw sql] (41, 12, 8, 1645045098000)
# 2022-02-16 21:00:19,447 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:19,691 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:19,694 INFO sqlalchemy.engine.Engine [raw sql] (3, 12, 8, 1645044703000)
# 2022-02-16 21:00:19,803 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:20,041 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:20,057 INFO sqlalchemy.engine.Engine [raw sql] (40, 19, 2, 1645045073000)
# 2022-02-16 21:00:20,168 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:20,413 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:20,413 INFO sqlalchemy.engine.Engine [raw sql] (29, 13, 16, 1645044849000)
# 2022-02-16 21:00:20,536 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:20,779 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:20,779 INFO sqlalchemy.engine.Engine [raw sql] (103, 15, 25, 1645044610000)
# 2022-02-16 21:00:20,905 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:21,147 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:21,147 INFO sqlalchemy.engine.Engine [raw sql] (28, 22, 8, 1645044721000)
# 2022-02-16 21:00:21,266 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:21,504 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:21,504 INFO sqlalchemy.engine.Engine [raw sql] (39, 4, 16, 1645044709000)
# 2022-02-16 21:00:21,623 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:21,871 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:21,871 INFO sqlalchemy.engine.Engine [raw sql] (83, 23, 17, 1645044934000)
# 2022-02-16 21:00:21,985 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:22,227 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:22,243 INFO sqlalchemy.engine.Engine [raw sql] (92, 14, 26, 1645045117000)
# 2022-02-16 21:00:22,351 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:22,601 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:22,601 INFO sqlalchemy.engine.Engine [raw sql] (21, 9, 21, 1645044721000)
# 2022-02-16 21:00:22,732 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:00:22,967 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:00:22,983 INFO sqlalchemy.engine.Engine [raw sql] (88, 24, 6, 1645045077000)
# 2022-02-16 21:00:23,101 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:23,584 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:23,590 INFO sqlalchemy.engine.Engine [raw sql] (42, 30, 0, 1645045236000)
# 2022-02-16 21:05:23,714 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:23,964 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:23,964 INFO sqlalchemy.engine.Engine [raw sql] (30, 1, 19, 1645045183000)
# 2022-02-16 21:05:24,083 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:24,325 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:24,325 INFO sqlalchemy.engine.Engine [raw sql] (54, 19, 14, 1645045324000)
# 2022-02-16 21:05:24,446 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:24,687 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:24,687 INFO sqlalchemy.engine.Engine [raw sql] (108, 16, 19, 1645044957000)
# 2022-02-16 21:05:24,810 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:25,045 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:25,046 INFO sqlalchemy.engine.Engine [raw sql] (56, 15, 25, 1645045056000)
# 2022-02-16 21:05:25,165 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:25,414 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:25,415 INFO sqlalchemy.engine.Engine [raw sql] (6, 3, 17, 1645045485000)
# 2022-02-16 21:05:25,533 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:25,770 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:25,771 INFO sqlalchemy.engine.Engine [raw sql] (18, 25, 5, 1645045034000)
# 2022-02-16 21:05:25,890 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:26,127 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:26,128 INFO sqlalchemy.engine.Engine [raw sql] (32, 4, 26, 1645044983000)
# 2022-02-16 21:05:26,245 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:26,486 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:26,487 INFO sqlalchemy.engine.Engine [raw sql] (52, 2, 30, 1645045109000)
# 2022-02-16 21:05:26,605 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:26,846 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:26,847 INFO sqlalchemy.engine.Engine [raw sql] (48, 19, 21, 1645045504000)
# 2022-02-16 21:05:26,967 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:27,203 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:27,204 INFO sqlalchemy.engine.Engine [raw sql] (13, 7, 23, 1645045180000)
# 2022-02-16 21:05:27,322 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:27,552 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:27,560 INFO sqlalchemy.engine.Engine [raw sql] (43, 30, 0, 1645044998000)
# 2022-02-16 21:05:27,663 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:27,914 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:27,917 INFO sqlalchemy.engine.Engine [raw sql] (31, 3, 17, 1645045515000)
# 2022-02-16 21:05:28,030 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:28,268 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:28,275 INFO sqlalchemy.engine.Engine [raw sql] (98, 2, 38, 1645045075000)
# 2022-02-16 21:05:28,387 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:28,624 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:28,630 INFO sqlalchemy.engine.Engine [raw sql] (23, 25, 5, 1645045326000)
# 2022-02-16 21:05:28,746 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:28,988 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:28,989 INFO sqlalchemy.engine.Engine [raw sql] (106, 22, 18, 1645045260000)
# 2022-02-16 21:05:29,105 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:29,338 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:29,352 INFO sqlalchemy.engine.Engine [raw sql] (112, 16, 14, 1645045467000)
# 2022-02-16 21:05:29,464 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:29,705 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:29,710 INFO sqlalchemy.engine.Engine [raw sql] (68, 2, 38, 1645045109000)
# 2022-02-16 21:05:29,824 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:30,066 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:30,068 INFO sqlalchemy.engine.Engine [raw sql] (74, 20, 10, 1645045459000)
# 2022-02-16 21:05:30,177 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:30,427 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:30,436 INFO sqlalchemy.engine.Engine [raw sql] (87, 8, 30, 1645044957000)
# 2022-02-16 21:05:30,552 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:30,785 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:30,790 INFO sqlalchemy.engine.Engine [raw sql] (84, 17, 13, 1645045454000)
# 2022-02-16 21:05:30,898 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:31,141 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:31,149 INFO sqlalchemy.engine.Engine [raw sql] (90, 2, 38, 1645045485000)
# 2022-02-16 21:05:31,261 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:31,506 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:31,510 INFO sqlalchemy.engine.Engine [raw sql] (11, 5, 25, 1645045139000)
# 2022-02-16 21:05:31,626 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:31,857 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:31,868 INFO sqlalchemy.engine.Engine [raw sql] (17, 6, 14, 1645045361000)
# 2022-02-16 21:05:31,980 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:32,221 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:32,226 INFO sqlalchemy.engine.Engine [raw sql] (45, 20, 10, 1645045229000)
# 2022-02-16 21:05:32,346 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:32,596 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:32,601 INFO sqlalchemy.engine.Engine [raw sql] (114, 0, 40, 1645045183000)
# 2022-02-16 21:05:32,719 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:32,958 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:32,960 INFO sqlalchemy.engine.Engine [raw sql] (72, 1, 30, 1645045337000)
# 2022-02-16 21:05:33,072 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:33,314 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:33,315 INFO sqlalchemy.engine.Engine [raw sql] (63, 11, 24, 1645045218000)
# 2022-02-16 21:05:33,418 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:33,670 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:33,675 INFO sqlalchemy.engine.Engine [raw sql] (113, 16, 24, 1645045276000)
# 2022-02-16 21:05:33,794 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:34,044 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:34,045 INFO sqlalchemy.engine.Engine [raw sql] (91, 27, 3, 1645045024000)
# 2022-02-16 21:05:34,156 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:34,400 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:34,404 INFO sqlalchemy.engine.Engine [raw sql] (99, 0, 30, 1645044913000)
# 2022-02-16 21:05:34,518 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:34,763 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:34,766 INFO sqlalchemy.engine.Engine [raw sql] (9, 18, 6, 1645045109000)
# 2022-02-16 21:05:34,884 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:35,122 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:35,123 INFO sqlalchemy.engine.Engine [raw sql] (67, 31, 9, 1645045253000)
# 2022-02-16 21:05:35,240 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:35,482 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:35,483 INFO sqlalchemy.engine.Engine [raw sql] (116, 20, 10, 1645045027000)
# 2022-02-16 21:05:35,604 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:35,848 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:35,849 INFO sqlalchemy.engine.Engine [raw sql] (55, 0, 36, 1645045112000)
# 2022-02-16 21:05:35,967 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:36,204 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:36,206 INFO sqlalchemy.engine.Engine [raw sql] (62, 0, 40, 1645044937000)
# 2022-02-16 21:05:36,312 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:36,553 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:36,553 INFO sqlalchemy.engine.Engine [raw sql] (5, 24, 16, 1645045389000)
# 2022-02-16 21:05:36,681 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:36,917 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:36,917 INFO sqlalchemy.engine.Engine [raw sql] (97, 26, 14, 1645045149000)
# 2022-02-16 21:05:37,036 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:37,288 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:37,288 INFO sqlalchemy.engine.Engine [raw sql] (61, 4, 21, 1645045347000)
# 2022-02-16 21:05:37,396 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:37,640 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:37,640 INFO sqlalchemy.engine.Engine [raw sql] (77, 18, 11, 1645045204000)
# 2022-02-16 21:05:37,773 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:38,014 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:38,014 INFO sqlalchemy.engine.Engine [raw sql] (73, 4, 26, 1645045407000)
# 2022-02-16 21:05:38,123 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:38,371 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:38,371 INFO sqlalchemy.engine.Engine [raw sql] (4, 3, 17, 1645045136000)
# 2022-02-16 21:05:38,495 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:38,741 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:38,741 INFO sqlalchemy.engine.Engine [raw sql] (49, 21, 19, 1645045083000)
# 2022-02-16 21:05:38,860 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:39,100 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:39,100 INFO sqlalchemy.engine.Engine [raw sql] (19, 1, 29, 1645045433000)
# 2022-02-16 21:05:39,212 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:39,463 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:39,467 INFO sqlalchemy.engine.Engine [raw sql] (7, 10, 19, 1645045464000)
# 2022-02-16 21:05:39,593 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:39,823 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:39,823 INFO sqlalchemy.engine.Engine [raw sql] (60, 25, 5, 1645045116000)
# 2022-02-16 21:05:39,951 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:40,215 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:40,216 INFO sqlalchemy.engine.Engine [raw sql] (102, 14, 26, 1645045316000)
# 2022-02-16 21:05:40,336 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:40,563 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:40,563 INFO sqlalchemy.engine.Engine [raw sql] (38, 26, 14, 1645044948000)
# 2022-02-16 21:05:40,680 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:40,934 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:40,934 INFO sqlalchemy.engine.Engine [raw sql] (53, 4, 36, 1645045121000)
# 2022-02-16 21:05:41,055 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:41,290 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:41,290 INFO sqlalchemy.engine.Engine [raw sql] (58, 15, 25, 1645045021000)
# 2022-02-16 21:05:41,416 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:41,657 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:41,657 INFO sqlalchemy.engine.Engine [raw sql] (66, 22, 18, 1645044953000)
# 2022-02-16 21:05:41,791 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:42,032 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:42,033 INFO sqlalchemy.engine.Engine [raw sql] (104, 8, 32, 1645045298000)
# 2022-02-16 21:05:42,139 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:42,386 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:42,386 INFO sqlalchemy.engine.Engine [raw sql] (101, 18, 12, 1645045461000)
# 2022-02-16 21:05:42,506 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:42,754 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:42,754 INFO sqlalchemy.engine.Engine [raw sql] (115, 23, 7, 1645045368000)
# 2022-02-16 21:05:42,880 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:43,124 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:43,125 INFO sqlalchemy.engine.Engine [raw sql] (47, 3, 37, 1645045111000)
# 2022-02-16 21:05:43,247 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:43,477 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:43,492 INFO sqlalchemy.engine.Engine [raw sql] (117, 11, 29, 1645044960000)
# 2022-02-16 21:05:43,612 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:43,852 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:43,852 INFO sqlalchemy.engine.Engine [raw sql] (8, 20, 10, 1645045420000)
# 2022-02-16 21:05:43,985 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:44,224 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:44,233 INFO sqlalchemy.engine.Engine [raw sql] (27, 0, 20, 1645045372000)
# 2022-02-16 21:05:44,348 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:44,591 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:44,595 INFO sqlalchemy.engine.Engine [raw sql] (16, 15, 5, 1645045145000)
# 2022-02-16 21:05:44,713 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:44,954 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:44,955 INFO sqlalchemy.engine.Engine [raw sql] (96, 19, 11, 1645045216000)
# 2022-02-16 21:05:45,060 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:45,311 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:45,311 INFO sqlalchemy.engine.Engine [raw sql] (82, 14, 8, 1645045154000)
# 2022-02-16 21:05:45,432 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:45,667 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:45,667 INFO sqlalchemy.engine.Engine [raw sql] (76, 14, 24, 1645045434000)
# 2022-02-16 21:05:45,794 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:46,042 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:46,044 INFO sqlalchemy.engine.Engine [raw sql] (71, 4, 36, 1645045347000)
# 2022-02-16 21:05:46,163 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:46,409 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:46,409 INFO sqlalchemy.engine.Engine [raw sql] (79, 15, 12, 1645045061000)
# 2022-02-16 21:05:46,544 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:46,776 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:46,776 INFO sqlalchemy.engine.Engine [raw sql] (69, 23, 17, 1645045464000)
# 2022-02-16 21:05:46,904 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:47,144 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:47,144 INFO sqlalchemy.engine.Engine [raw sql] (25, 1, 29, 1645045099000)
# 2022-02-16 21:05:47,261 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:47,517 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:47,517 INFO sqlalchemy.engine.Engine [raw sql] (51, 3, 37, 1645045461000)
# 2022-02-16 21:05:47,640 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:47,879 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:47,881 INFO sqlalchemy.engine.Engine [raw sql] (37, 7, 23, 1645045104000)
# 2022-02-16 21:05:47,994 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:48,234 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:48,234 INFO sqlalchemy.engine.Engine [raw sql] (59, 6, 13, 1645045327000)
# 2022-02-16 21:05:48,352 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:48,590 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:48,591 INFO sqlalchemy.engine.Engine [raw sql] (95, 10, 30, 1645045058000)
# 2022-02-16 21:05:48,712 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:48,939 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:48,955 INFO sqlalchemy.engine.Engine [raw sql] (94, 3, 37, 1645045180000)
# 2022-02-16 21:05:49,065 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:49,305 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:49,310 INFO sqlalchemy.engine.Engine [raw sql] (105, 18, 18, 1645045150000)
# 2022-02-16 21:05:49,421 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:49,672 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:49,673 INFO sqlalchemy.engine.Engine [raw sql] (36, 11, 29, 1645045245000)
# 2022-02-16 21:05:49,789 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:50,029 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:50,030 INFO sqlalchemy.engine.Engine [raw sql] (93, 4, 36, 1645044983000)
# 2022-02-16 21:05:50,146 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:50,387 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:50,388 INFO sqlalchemy.engine.Engine [raw sql] (22, 17, 3, 1645045335000)
# 2022-02-16 21:05:50,506 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:50,743 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:50,744 INFO sqlalchemy.engine.Engine [raw sql] (50, 25, 15, 1645044976000)
# 2022-02-16 21:05:50,864 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:51,105 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:51,106 INFO sqlalchemy.engine.Engine [raw sql] (110, 23, 17, 1645044915000)
# 2022-02-16 21:05:51,221 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:51,465 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:51,466 INFO sqlalchemy.engine.Engine [raw sql] (12, 15, 5, 1645045460000)
# 2022-02-16 21:05:51,589 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:51,828 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:51,830 INFO sqlalchemy.engine.Engine [raw sql] (34, 30, 0, 1645045271000)
# 2022-02-16 21:05:51,939 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:52,197 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:52,197 INFO sqlalchemy.engine.Engine [raw sql] (78, 3, 37, 1645045368000)
# 2022-02-16 21:05:52,320 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 21:05:52,562 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 21:05:52,562 INFO sqlalchemy.engine.Engine [raw sql] (2, 10, 10, 1645045339000)
# ...
# 2022-02-16 23:16:14,845 INFO sqlalchemy.engine.Engine [raw sql] (102, 15, 25, 1645053130000)
# 2022-02-16 23:16:14,962 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:15,212 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:15,213 INFO sqlalchemy.engine.Engine [raw sql] (38, 27, 13, 1645052870000)
# 2022-02-16 23:16:15,333 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:15,574 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:15,576 INFO sqlalchemy.engine.Engine [raw sql] (53, 3, 37, 1645053162000)
# 2022-02-16 23:16:15,695 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:15,945 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:15,946 INFO sqlalchemy.engine.Engine [raw sql] (58, 12, 28, 1645053257000)
# 2022-02-16 23:16:16,065 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:16,308 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:16,310 INFO sqlalchemy.engine.Engine [raw sql] (66, 23, 17, 1645052928000)
# 2022-02-16 23:16:16,415 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:16,672 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:16,673 INFO sqlalchemy.engine.Engine [raw sql] (104, 8, 32, 1645053180000)
# 2022-02-16 23:16:16,796 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:17,034 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:17,035 INFO sqlalchemy.engine.Engine [raw sql] (101, 18, 12, 1645052858000)
# 2022-02-16 23:16:17,148 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:17,397 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:17,397 INFO sqlalchemy.engine.Engine [raw sql] (115, 30, 0, 1645053114000)
# 2022-02-16 23:16:17,520 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:17,760 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:17,762 INFO sqlalchemy.engine.Engine [raw sql] (47, 1, 39, 1645052975000)
# 2022-02-16 23:16:17,886 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:18,128 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:18,130 INFO sqlalchemy.engine.Engine [raw sql] (117, 9, 31, 1645052771000)
# 2022-02-16 23:16:18,246 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:18,494 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:18,496 INFO sqlalchemy.engine.Engine [raw sql] (8, 18, 12, 1645052859000)
# 2022-02-16 23:16:18,612 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:18,846 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:18,861 INFO sqlalchemy.engine.Engine [raw sql] (27, 0, 20, 1645053097000)
# 2022-02-16 23:16:18,979 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:19,212 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:19,212 INFO sqlalchemy.engine.Engine [raw sql] (16, 14, 6, 1645053284000)
# 2022-02-16 23:16:19,344 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:19,582 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:19,584 INFO sqlalchemy.engine.Engine [raw sql] (96, 20, 10, 1645053252000)
# 2022-02-16 23:16:19,695 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:19,943 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:19,943 INFO sqlalchemy.engine.Engine [raw sql] (82, 14, 8, 1645052945000)
# 2022-02-16 23:16:20,058 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:20,294 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:20,309 INFO sqlalchemy.engine.Engine [raw sql] (76, 17, 21, 1645052987000)
# 2022-02-16 23:16:20,427 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:20,660 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:20,660 INFO sqlalchemy.engine.Engine [raw sql] (71, 1, 39, 1645053073000)
# 2022-02-16 23:16:20,790 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:21,026 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:21,041 INFO sqlalchemy.engine.Engine [raw sql] (79, 14, 13, 1645053269000)
# 2022-02-16 23:16:21,159 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:21,406 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:21,410 INFO sqlalchemy.engine.Engine [raw sql] (69, 23, 17, 1645053274000)
# 2022-02-16 23:16:21,523 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:21,774 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:21,779 INFO sqlalchemy.engine.Engine [raw sql] (25, 1, 29, 1645052976000)
# 2022-02-16 23:16:21,899 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:22,139 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:22,144 INFO sqlalchemy.engine.Engine [raw sql] (51, 1, 39, 1645052800000)
# 2022-02-16 23:16:22,255 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:22,518 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:22,523 INFO sqlalchemy.engine.Engine [raw sql] (37, 5, 25, 1645052851000)
# 2022-02-16 23:16:22,637 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:22,882 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:22,885 INFO sqlalchemy.engine.Engine [raw sql] (59, 8, 11, 1645053114000)
# 2022-02-16 23:16:22,991 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:23,247 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:23,250 INFO sqlalchemy.engine.Engine [raw sql] (95, 13, 27, 1645052892000)
# 2022-02-16 23:16:23,371 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:23,607 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:23,607 INFO sqlalchemy.engine.Engine [raw sql] (94, 3, 37, 1645052914000)
# 2022-02-16 23:16:23,724 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:23,982 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:23,987 INFO sqlalchemy.engine.Engine [raw sql] (105, 19, 17, 1645053237000)
# 2022-02-16 23:16:24,102 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:24,343 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:24,344 INFO sqlalchemy.engine.Engine [raw sql] (36, 11, 29, 1645052801000)
# 2022-02-16 23:16:24,456 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:24,706 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:24,710 INFO sqlalchemy.engine.Engine [raw sql] (93, 4, 36, 1645052866000)
# 2022-02-16 23:16:24,822 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:25,066 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:25,068 INFO sqlalchemy.engine.Engine [raw sql] (22, 11, 9, 1645053236000)
# 2022-02-16 23:16:25,191 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:25,433 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:25,436 INFO sqlalchemy.engine.Engine [raw sql] (50, 30, 10, 1645053152000)
# 2022-02-16 23:16:25,551 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:25,787 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:25,787 INFO sqlalchemy.engine.Engine [raw sql] (110, 19, 21, 1645053287000)
# 2022-02-16 23:16:25,921 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:26,162 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:26,162 INFO sqlalchemy.engine.Engine [raw sql] (12, 16, 4, 1645053200000)
# 2022-02-16 23:16:26,284 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:26,529 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:26,531 INFO sqlalchemy.engine.Engine [raw sql] (34, 27, 3, 1645053234000)
# 2022-02-16 23:16:26,648 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:26,873 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:26,891 INFO sqlalchemy.engine.Engine [raw sql] (78, 5, 35, 1645053287000)
# 2022-02-16 23:16:27,008 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:27,236 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:27,236 INFO sqlalchemy.engine.Engine [raw sql] (2, 12, 8, 1645053105000)
# 2022-02-16 23:16:27,354 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:27,604 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:27,604 INFO sqlalchemy.engine.Engine [raw sql] (75, 37, 3, 1645052719000)
# 2022-02-16 23:16:27,719 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:27,965 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:27,965 INFO sqlalchemy.engine.Engine [raw sql] (111, 12, 28, 1645053108000)
# 2022-02-16 23:16:28,084 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:28,324 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:28,339 INFO sqlalchemy.engine.Engine [raw sql] (26, 0, 20, 1645052894000)
# 2022-02-16 23:16:28,449 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:28,702 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:28,705 INFO sqlalchemy.engine.Engine [raw sql] (65, 2, 38, 1645052840000)
# 2022-02-16 23:16:28,817 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:29,059 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:29,059 INFO sqlalchemy.engine.Engine [raw sql] (15, 16, 0, 1645052881000)
# 2022-02-16 23:16:29,185 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:29,418 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:29,418 INFO sqlalchemy.engine.Engine [raw sql] (86, 17, 21, 1645053229000)
# 2022-02-16 23:16:29,550 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:29,781 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:29,781 INFO sqlalchemy.engine.Engine [raw sql] (10, 11, 5, 1645053118000)
# 2022-02-16 23:16:29,906 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:30,148 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:30,148 INFO sqlalchemy.engine.Engine [raw sql] (100, 22, 3, 1645052855000)
# 2022-02-16 23:16:30,266 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:30,515 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:30,516 INFO sqlalchemy.engine.Engine [raw sql] (24, 19, 1, 1645053001000)
# 2022-02-16 23:16:30,635 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:30,877 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:30,877 INFO sqlalchemy.engine.Engine [raw sql] (64, 9, 31, 1645053024000)
# 2022-02-16 23:16:30,994 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:31,236 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:31,236 INFO sqlalchemy.engine.Engine [raw sql] (109, 24, 5, 1645053090000)
# 2022-02-16 23:16:31,363 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:31,598 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:31,598 INFO sqlalchemy.engine.Engine [raw sql] (85, 18, 17, 1645052838000)
# 2022-02-16 23:16:31,724 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:31,962 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:31,962 INFO sqlalchemy.engine.Engine [raw sql] (107, 22, 18, 1645052911000)
# 2022-02-16 23:16:32,081 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:32,332 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:32,334 INFO sqlalchemy.engine.Engine [raw sql] (33, 10, 13, 1645052716000)
# 2022-02-16 23:16:32,454 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:32,694 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:32,695 INFO sqlalchemy.engine.Engine [raw sql] (44, 16, 14, 1645053104000)
# 2022-02-16 23:16:32,815 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:33,060 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:33,062 INFO sqlalchemy.engine.Engine [raw sql] (89, 1, 39, 1645053211000)
# 2022-02-16 23:16:33,183 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:33,425 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:33,430 INFO sqlalchemy.engine.Engine [raw sql] (57, 6, 17, 1645052787000)
# 2022-02-16 23:16:33,546 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:33,793 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:33,794 INFO sqlalchemy.engine.Engine [raw sql] (80, 10, 30, 1645053116000)
# 2022-02-16 23:16:33,915 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:34,146 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:34,161 INFO sqlalchemy.engine.Engine [raw sql] (41, 11, 9, 1645052983000)
# 2022-02-16 23:16:34,281 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:34,522 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:34,523 INFO sqlalchemy.engine.Engine [raw sql] (3, 9, 11, 1645053122000)
# 2022-02-16 23:16:34,642 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:34,864 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:34,882 INFO sqlalchemy.engine.Engine [raw sql] (40, 12, 9, 1645053092000)
# 2022-02-16 23:16:35,002 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:35,233 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:35,233 INFO sqlalchemy.engine.Engine [raw sql] (29, 15, 14, 1645053114000)
# 2022-02-16 23:16:35,360 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:35,592 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:35,607 INFO sqlalchemy.engine.Engine [raw sql] (103, 10, 30, 1645053116000)
# 2022-02-16 23:16:35,730 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:35,970 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:35,971 INFO sqlalchemy.engine.Engine [raw sql] (28, 25, 5, 1645052768000)
# 2022-02-16 23:16:36,075 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:36,343 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:36,345 INFO sqlalchemy.engine.Engine [raw sql] (39, 2, 18, 1645052950000)
# 2022-02-16 23:16:36,456 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:36,691 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:36,691 INFO sqlalchemy.engine.Engine [raw sql] (83, 23, 17, 1645052945000)
# 2022-02-16 23:16:36,807 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:37,055 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:37,055 INFO sqlalchemy.engine.Engine [raw sql] (92, 15, 25, 1645053187000)
# 2022-02-16 23:16:37,185 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:37,418 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:37,418 INFO sqlalchemy.engine.Engine [raw sql] (21, 8, 22, 1645052784000)
# 2022-02-16 23:16:37,551 INFO sqlalchemy.engine.Engine COMMIT
# 2022-02-16 23:16:37,786 INFO sqlalchemy.engine.Engine insert into availability values(%s,%s,%s,%s)
# 2022-02-16 23:16:37,786 INFO sqlalchemy.engine.Engine [raw sql] (88, 27, 3, 1645052912000)
# 2022-02-16 23:16:37,903 INFO sqlalchemy.engine.Engine COMMIT

# %%
def stations_to_db(text):
    stations = json.loads(text)
    print(stations)
    print(type(stations), len(stations))
    for station in stations:
        print(station)
        vals = (station.get("address"),int(station.get("banking")),
               station.get("bike_stands"),(station.get("address")),
                station.get("contract_name"),station.get("name"),
                station.get("number"),station.get("position").get("lat"),
               station.get("position").get("lng"), station.get("status")
               )
        engine.execute("insert into station values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",vals)
#         break
    return
stations_to_db(r.text)

# %%
metadata = sqla.MetaData()
# station = sqla.Table("station", metadata,
# sqla.Column('address',sqla.String(256), nullable=False),
# sqla.Column('banking', sqla.INTEGER),
# sqla.Column('bike_stands', sqla.INTEGER),
# sqla.Column('bonus', sqla.INTEGER),
# sqla.Column('contract_name', sqla.String(256)),
# sqla.Column('number', sqla.INTEGER),
# sqla.Column('position_lat', sqla.REAL),
# sqla.Column('position_lng', sqla.REAL),
# sqla.Column('status', sqla.String(256))

# )

availability = sqla.Table("availability",metadata,
sqla.Column('available_bikes', sqla.Integer),
sqla.Column('available_bikes_stands', sqla.Integer),
sqla.Column('number', sqla.Integer),
sqla.Column('last_update', sqla.TIME)

)

try:
    station.drop(engine)
    availability.drop(engine)
except:
    pass

metadata.create_all(engine)

# %%
metadata = sqla.MetaData(bind=engine)
print(metadata)
station = sqla.Table('station', metadata, autoload=True)
print(station)

# %%
# def stations_fix_keys(station):
#     station['position_lat'] = station['position']['lat']
#     station['position_lng'] = station['position']['lng']
#     return station

# stations = json.loads(open('stations.json', 'r').read())
# engine.execute(station.insert(), *map(stations_fix_keys, stations))
